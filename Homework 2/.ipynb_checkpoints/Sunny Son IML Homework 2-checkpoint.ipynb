# %% [markdown]
# Imports for packages and modules to be used

# %%
# %pip install colorcet
# %pip install scikit-plot
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

import scipy.stats as st
import statsmodels.api as sm
from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler as sc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_validate, KFold, RepeatedKFold, GridSearchCV
from sklearn.metrics import mean_squared_error as mse
from sklearn import metrics

from tqdm import tqdm

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scikitplot as skplt
from matplotlib import mlab
import seaborn as sns; sns.set_theme(color_codes=True)
import colorcet as cc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25652/2936312764.py in <module>
#      16 from matplotlib import pyplot as plt
#      17 from mpl_toolkits.mplot3d import Axes3D
# ---> 18 import scikitplot as skplt
#      19 from matplotlib import mlab
#      20 import seaborn as sns; sns.set_theme(color_codes=True)
#
# ModuleNotFoundError: No module named 'scikitplot'

# %% [markdown]
# # Question 0 - Methods & DIsclosures
#
# For the remainder of this analysis, I will be using row-wise removal for all of any and all `NA` values in ths dataset provided. I considered attempting row-wise removal on portions of analysis attributed to each section, but then realized that in the full multiple-regression, results would not be able to be coordinated by not using the same dataset for each question.
#
# Below are printouts of the `shape`, `dtypes`, `head(50)`, and `describe()` of the dataset.

# %%
df = pd.read_csv('techSalaries2017.csv')
df_dropna = df.dropna(axis=0)

print('<====================shapes====================>')
print(df_dropna.shape)
print('<====================data types====================>')
print(df_dropna.dtypes)
print('<====================describe====================>')
df_dropna.describe()
# Out:
# <====================shapes====================>
# (21589, 27)
# <====================data types====================>
# company                     object
# title                       object
# location                    object
# totalyearlycompensation      int64
# basesalary                   int64
# stockgrantvalue            float64
# bonus                      float64
# yearsofexperience          float64
# yearsatcompany             float64
# gender                      object
# Masters_Degree               int64
# Bachelors_Degree             int64
# Doctorate_Degree             int64
# Highschool                   int64
# Some_College                 int64
# Race_Asian                   int64
# Race_White                   int64
# Race_Two_Or_More             int64
# Race_Black                   int64
# Race_Hispanic                int64
# Race                        object
# Education                   object
# Age                          int64
# Height                     float64
# Zodiac                       int64
# SAT                          int64
# GPA                        float64
# dtype: object
# <====================describe====================>
#        totalyearlycompensation     basesalary  stockgrantvalue          bonus  \
# count             2.158900e+04   21589.000000     21589.000000   21589.000000
# mean              1.978564e+05  133867.061930     44894.393117   18416.740006
# std               1.330941e+05   57215.090953     72451.815319   25083.767009
# min               1.000000e+04    4000.000000         0.000000       0.000000
# 25%               1.190000e+05  100000.000000         0.000000    3000.000000
# 50%               1.740000e+05  135000.000000     20000.000000   13000.000000
# 75%               2.450000e+05  165000.000000     55000.000000   25000.000000
# max               4.980000e+06  900000.000000    954000.000000  900000.000000
#
#        yearsofexperience  yearsatcompany  Masters_Degree  Bachelors_Degree  \
# count       21589.000000    21589.000000    21589.000000      21589.000000
# mean            7.122331        2.703460        0.421233          0.506462
# std             5.847595        3.325033        0.493768          0.499970
# min             0.000000        0.000000        0.000000          0.000000
# 25%             3.000000        0.000000        0.000000          0.000000
# 50%             6.000000        2.000000        0.000000          1.000000
# 75%            10.000000        4.000000        1.000000          1.000000
# max            45.000000       40.000000        1.000000          1.000000
#
#        Doctorate_Degree    Highschool  ...    Race_Asian    Race_White  \
# count       21589.00000  21589.000000  ...  21589.000000  21589.000000
# mean            0.04280      0.013942  ...      0.528695      0.355737
# std             0.20241      0.117254  ...      0.499187      0.478747
# min             0.00000      0.000000  ...      0.000000      0.000000
# 25%             0.00000      0.000000  ...      0.000000      0.000000
# 50%             0.00000      0.000000  ...      1.000000      0.000000
# 75%             0.00000      0.000000  ...      1.000000      1.000000
# max             1.00000      1.000000  ...      1.000000      1.000000
#
#        Race_Two_Or_More    Race_Black  Race_Hispanic           Age  \
# count      21589.000000  21589.000000   21589.000000  21589.000000
# mean           0.035481      0.030664       0.049470     37.158090
# std            0.184997      0.172409       0.216851      9.271464
# min            0.000000      0.000000       0.000000     18.000000
# 25%            0.000000      0.000000       0.000000     30.000000
# 50%            0.000000      0.000000       0.000000     37.000000
# 75%            0.000000      0.000000       0.000000     43.000000
# max            1.000000      1.000000       1.000000     82.000000
#
#              Height        Zodiac           SAT           GPA
# count  21589.000000  21589.000000  21589.000000  21589.000000
# mean      66.995702      6.478994   1072.179119      2.902703
# std        3.003608      3.449843    117.441700      0.278387
# min       54.820000      1.000000    400.000000      1.000000
# 25%       64.964000      3.000000   1004.000000      2.740000
# 50%       66.992000      6.000000   1083.000000      2.930000
# 75%       69.038000      9.000000   1151.000000      3.090000
# max       80.368000     12.000000   1600.000000      4.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# FInally, we will head the dataframe headder with dropped `NA`'s:

# %%
# Set n for how many to head
n = 10
print('<====================head(50)====================>')
df_dropna.head(n)
# Out:
# <====================head(50)====================>
#          company                         title               location  \
# 15710     Google             Software Engineer          Sunnyvale, CA
# 23532  Microsoft             Software Engineer            Redmond, WA
# 23533     Google             Software Engineer          San Bruno, CA
# 23534  Microsoft             Software Engineer            Seattle, WA
# 23535      Blend             Software Engineer      San Francisco, CA
# 23537     Amazon             Software Engineer            Seattle, WA
# 23538    Chevron             Software Engineer            Houston, TX
# 23540     Amazon  Software Engineering Manager            Seattle, WA
# 23541    Shopify             Software Engineer    Toronto, ON, Canada
# 23543      Apple             Software Engineer  Vancouver, BC, Canada
#
#        totalyearlycompensation  basesalary  stockgrantvalue    bonus  \
# 15710                   400000      210000         145000.0  45000.0
# 23532                   136000      124000           1000.0  11000.0
# 23533                   337000      177000         125000.0  36000.0
# 23534                   222000      164000          38000.0  20000.0
# 23535                   187000      165000          22000.0      0.0
# 23537                   310000      160000         150000.0      0.0
# 23538                   113000      103000              0.0  10000.0
# 23540                   620000      160000         460000.0      0.0
# 23541                    98000       78000          20000.0      0.0
# 23543                   180000      130000          30000.0  20000.0
#
#        yearsofexperience  yearsatcompany gender  ...  Race_Two_Or_More  \
# 15710                5.0             5.0   Male  ...                 0
# 23532                3.0             2.0   Male  ...                 1
# 23533                6.0             6.0   Male  ...                 0
# 23534                4.0             4.0   Male  ...                 0
# 23535                5.0             0.0   Male  ...                 0
# 23537               15.0             3.0   Male  ...                 0
# 23538                3.0             3.0   Male  ...                 0
# 23540               19.0             7.0   Male  ...                 0
# 23541                9.0             4.0   Male  ...                 0
# 23543                1.0             1.0   Male  ...                 0
#
#        Race_Black  Race_Hispanic         Race          Education  Age  Height  \
# 15710           0              0        Asian                PhD   45  68.891
# 23532           0              0  Two Or More  Bachelor's Degree   24  61.454
# 23533           0              0        Asian  Bachelor's Degree   25  65.455
# 23534           0              0        Asian    Master's Degree   32  73.769
# 23535           0              0        White  Bachelor's Degree   29  68.710
# 23537           0              0        Asian  Bachelor's Degree   34  69.126
# 23538           0              1     Hispanic  Bachelor's Degree   23  66.406
# 23540           0              0        Asian  Bachelor's Degree   58  66.824
# 23541           0              0        Asian  Bachelor's Degree   27  63.777
# 23543           0              0        Asian  Bachelor's Degree   31  68.474
#
#        Zodiac   SAT   GPA
# 15710       9  1166  3.04
# 23532      12  1175  3.07
# 23533       1  1268  3.34
# 23534       8  1070  2.75
# 23535       2  1187  3.23
# 23537       9  1196  3.28
# 23538       2   992  2.66
# 23540       2  1185  2.99
# 23541      10   991  2.92
# 23543      10   978  2.74
#
# [10 rows x 27 columns]

# %% [markdown]
# Knowing that there are no longer any non-applicable variables, we then remove over-determined dummy variables (specifically towards the set 11 to 15, 22 and 16 to 22), "Terminal Degree is some college (1 = yes)" (as per 3) in Hints).
#
# The following details methodologies surrounding variable handling and standardization:
#
# 1. While I have some personal compunction against the data stating the requirement of a degree (I have heard that it was possible to join tech companies in the '80's without a degree, but the plural of anecdote is not data so for the purposes of this analysis, I will remove it as per the understanding within 3) in Hints and require all individuals surveyed to have *some* kind of education).
#
# 2. "Self-identifies as Multi-Racial (1 = yes)" (any person must belong to one race - we are not counting extraterresterials - and will already reflect otherwise over-determined data).
#
# 3. I do not see the applicability for standardization, specifically: $$\frac{X - \mu}{\sigma}$$ when applied to **dummy/categorical** variables (except in the case for LASSO regression, which I determined by 3. in Citations), as well as all variables in Question 1) due to the lack of a need. For all other variables, standardization by the above equation will be performed.
#
# These previously listed procedures were carried out for the rest of the analysis.
#
# We then create a label out of `totalyearlycompensation`.

# %%
label = df_dropna[['totalyearlycompensation']]
label
# Out:
#        totalyearlycompensation
# 15710                   400000
# 23532                   136000
# 23533                   337000
# 23534                   222000
# 23535                   187000
# ...                        ...
# 61981                  1470000
# 61982                  4500000
# 61984                  1605000
# 61987                  2372000
# 61991                  4980000
#
# [21589 rows x 1 columns]

# %% [markdown]
# # Question 1
#
# Using multiple linear regression: What is the best predictor of total annual compensation, how much variance is explained by this predictor vs. the full multiple regression model?
#
# ## Answer
#
# For this question, I considered the availability of datatypes for our predictors, as well as cross-referencing the usefulness and reasonable validity of using each predictor in the model.
#
# Specifically:
# 1. For multiple-regression models with less predictors than the full multiple regression model, I assumed simple OLS models using one predictor mapped to predicting the given label. For this regression problem I considered utilizing individual one-predictor dummy regressions, but the decision to not do so is presented below.
#
# 2. For the full multiple-regression model, I utilized all variables except 1), 2), and 3) as per instructions.
#
# The predictors I thought valid for the single predictor OLS regression model are:
#
# 1. Total annual compensation (in $)
# 2. Years of relevant experience (in years)
# 3. Time with this company (in years)
# 4. Gender
# 5. 11\) to 15) Terminal Degree
# 6. 16\) to 20) Race
# 7. Age (in years)
# 8. Height (in inches)
# 9. Zodiac sign (Tropical calendar, 1 = Aries, 12 = Pisces, with everything else in between)
# 10. SAT score
# 11. GPA
#
# But, for 4\., 5\., 6\., and 9\. listed above, variables are dummies/discrete, and thus should be handled carefully. I will nonetheless run a linear regression on these, but for seaprate consideration below.

# %%
predictors = df_dropna[['Masters_Degree','Bachelors_Degree',
                        'Doctorate_Degree','Highschool']]

title_map = {'Masters_Degree': 'Master\'s Degree',
             'Bachelors_Degree': 'Bachelor\'s Degree',
             'Doctorate_Degree': 'Doctorate Degree',
             'Highschool': 'High School Degree'}

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20,11))
fig.suptitle('Potential Dummy Variable Plots Based on Degree', fontsize=20, y=0.95)

colors = ['r','g','b','y']

iter_col = iter(colors)

for pred, ax in zip(predictors, axs.ravel()):
    x = pd.DataFrame(predictors[pred], columns=[pred])
    y = label

    ols = LinearRegression().fit(x,y)
    y_hat = ols.predict(x)
    score = ols.score(x,y)
    rmse = (np.sqrt(mse(y, y_hat)))

    x_lin = np.linspace(0, x.max(), 100)
    lin_pred = ols.predict(x_lin)

    # ax.plot(x,y,'+', color=next(iter_col))
    # ax.plot(x_lin, lin_pred, color='black')

    sns.regplot(x=pred, y='totalyearlycompensation', data=df_dropna, ax=ax, color=next(iter_col), marker='+')

    ax.set_title(f'{title_map[pred]}, $R^{2}$: {score:.4f}, $RMSE$: \${rmse:.2f} USD')
    ax.set_ylabel('Total Yearly Compensation (Predicted)')
    ax.set_xlabel(f'1 - Yes {title_map[pred]}, 0 - No {title_map[pred]}')

# %%
corr = predictors.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/2151522955.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_550ac_row0_col0, #T_550ac_row1_col1, #T_550ac_row2_col2, #T_550ac_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_550ac_row0_col1, #T_550ac_row1_col0, #T_550ac_row1_col2, #T_550ac_row1_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_550ac_row0_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_550ac_row0_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_550ac_row2_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_550ac_row2_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_550ac_row2_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_550ac_row3_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_550ac_row3_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_550ac_row3_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_550ac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Masters_Degree</th>
#       <th class="col_heading level0 col1" >Bachelors_Degree</th>
#       <th class="col_heading level0 col2" >Doctorate_Degree</th>
#       <th class="col_heading level0 col3" >Highschool</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_550ac_level0_row0" class="row_heading level0 row0" >Masters_Degree</th>
#       <td id="T_550ac_row0_col0" class="data row0 col0" >1.0000000000</td>
#       <td id="T_550ac_row0_col1" class="data row0 col1" >-0.8636527875</td>
#       <td id="T_550ac_row0_col2" class="data row0 col2" >-0.1803962999</td>
#       <td id="T_550ac_row0_col3" class="data row0 col3" >-0.1014437188</td>
#     </tr>
#     <tr>
#       <th id="T_550ac_level0_row1" class="row_heading level0 row1" >Bachelors_Degree</th>
#       <td id="T_550ac_row1_col0" class="data row1 col0" >-0.8636527875</td>
#       <td id="T_550ac_row1_col1" class="data row1 col1" >1.0000000000</td>
#       <td id="T_550ac_row1_col2" class="data row1 col2" >-0.2142057322</td>
#       <td id="T_550ac_row1_col3" class="data row1 col3" >-0.1204560520</td>
#     </tr>
#     <tr>
#       <th id="T_550ac_level0_row2" class="row_heading level0 row2" >Doctorate_Degree</th>
#       <td id="T_550ac_row2_col0" class="data row2 col0" >-0.1803962999</td>
#       <td id="T_550ac_row2_col1" class="data row2 col1" >-0.2142057322</td>
#       <td id="T_550ac_row2_col2" class="data row2 col2" >1.0000000000</td>
#       <td id="T_550ac_row2_col3" class="data row2 col3" >-0.0251439844</td>
#     </tr>
#     <tr>
#       <th id="T_550ac_level0_row3" class="row_heading level0 row3" >Highschool</th>
#       <td id="T_550ac_row3_col0" class="data row3 col0" >-0.1014437188</td>
#       <td id="T_550ac_row3_col1" class="data row3 col1" >-0.1204560520</td>
#       <td id="T_550ac_row3_col2" class="data row3 col2" >-0.0251439844</td>
#       <td id="T_550ac_row3_col3" class="data row3 col3" >1.0000000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictors = df_dropna[['Race_Asian','Race_White',
                        'Race_Black','Race_Hispanic']]

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20,11))
fig.suptitle('Potential Dummy Variable Plots Based on Race', fontsize=20, y=0.95)

title_map = {'Race_Asian': 'Race: Asian',
             'Race_White': 'Race: White',
             'Race_Black': 'Race: Black',
             'Race_Hispanic': 'Race: Hispanic'}

colors = ['r','g','b','y']

iter_col = iter(colors)

for pred, ax in zip(predictors, axs.ravel()):

    x = pd.DataFrame(predictors[pred], columns=[pred])
    y = label

    ols = LinearRegression().fit(x,y)
    y_hat = ols.predict(x)
    score = ols.score(x,y)
    rmse = (np.sqrt(mse(y, y_hat)))

    x_lin = np.linspace(0, x.max(), 100)
    lin_pred = ols.predict(x_lin)

    #ax.plot(x,y,'+', color=next(iter_col))
    #ax.plot(x_lin, lin_pred, color='black')

    sns.regplot(x=pred, y='totalyearlycompensation', data=df_dropna, ax=ax, color=next(iter_col), marker='+',)

    ax.set_title(f'{title_map[pred]}, $R^{2}$: {score:.4f}, $RMSE$: \${rmse:.2f} USD')
    ax.set_ylabel('Total Yearly Compensation (Predicted)')
    ax.set_xlabel(f'1 - Yes {title_map[pred]}, 0 - No {title_map[pred]}')

# %%
corr = predictors.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/2151522955.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_e37a0_row0_col0, #T_e37a0_row1_col1, #T_e37a0_row2_col2, #T_e37a0_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e37a0_row0_col1, #T_e37a0_row0_col2, #T_e37a0_row0_col3, #T_e37a0_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e37a0_row1_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e37a0_row1_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e37a0_row2_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_e37a0_row2_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_e37a0_row2_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e37a0_row3_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e37a0_row3_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e37a0_row3_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e37a0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Race_Asian</th>
#       <th class="col_heading level0 col1" >Race_White</th>
#       <th class="col_heading level0 col2" >Race_Black</th>
#       <th class="col_heading level0 col3" >Race_Hispanic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e37a0_level0_row0" class="row_heading level0 row0" >Race_Asian</th>
#       <td id="T_e37a0_row0_col0" class="data row0 col0" >1.0000000000</td>
#       <td id="T_e37a0_row0_col1" class="data row0 col1" >-0.7870174859</td>
#       <td id="T_e37a0_row0_col2" class="data row0 col2" >-0.1883767209</td>
#       <td id="T_e37a0_row0_col3" class="data row0 col3" >-0.2411949804</td>
#     </tr>
#     <tr>
#       <th id="T_e37a0_level0_row1" class="row_heading level0 row1" >Race_White</th>
#       <td id="T_e37a0_row1_col0" class="data row1 col0" >-0.7870174859</td>
#       <td id="T_e37a0_row1_col1" class="data row1 col1" >1.0000000000</td>
#       <td id="T_e37a0_row1_col2" class="data row1 col2" >-0.1321624753</td>
#       <td id="T_e37a0_row1_col3" class="data row1 col3" >-0.1695192501</td>
#     </tr>
#     <tr>
#       <th id="T_e37a0_level0_row2" class="row_heading level0 row2" >Race_Black</th>
#       <td id="T_e37a0_row2_col0" class="data row2 col0" >-0.1883767209</td>
#       <td id="T_e37a0_row2_col1" class="data row2 col1" >-0.1321624753</td>
#       <td id="T_e37a0_row2_col2" class="data row2 col2" >1.0000000000</td>
#       <td id="T_e37a0_row2_col3" class="data row2 col3" >-0.0405753125</td>
#     </tr>
#     <tr>
#       <th id="T_e37a0_level0_row3" class="row_heading level0 row3" >Race_Hispanic</th>
#       <td id="T_e37a0_row3_col0" class="data row3 col0" >-0.2411949804</td>
#       <td id="T_e37a0_row3_col1" class="data row3 col1" >-0.1695192501</td>
#       <td id="T_e37a0_row3_col2" class="data row3 col2" >-0.0405753125</td>
#       <td id="T_e37a0_row3_col3" class="data row3 col3" >1.0000000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With large $RMSE$'s (in terms of total yearly compensation) and miniscule $R^{2}$ scores, it would not make sense to use each (any) of these variables as sole predictors toward the label (not that it would have counted in the first place due to such dismal scores).
#
# Another variable I would like to explore individually is gender, however as this variable is the focus of Question 4, I will include a simple regression (through dummy variables) but solely utilize derived $RMSE$ and $R^{2}$ values.

# %%
predictors_gend = pd.get_dummies(df_dropna[['gender']], prefix=[''], 
                                 prefix_sep='')[['Male','Female']]

concat = pd.concat([predictors_gend,label], axis=1)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,7))
fig.suptitle('Dummy Variable Plots Based on Gender', fontsize=20, y=0.95)

title_map = {'Female': 'Female Tech Employees',
             'Male': 'Male Tech Employees'}

colors = ['r','g','b','y','orange']

iter_col = iter(colors)

for pred, ax in zip(predictors_gend, axs.ravel()):
    x = pd.DataFrame(predictors_gend[pred], columns=[pred])
    y = label

    ols = LinearRegression().fit(x,y)
    y_hat = ols.predict(x)
    score = ols.score(x,y)
    rmse = (np.sqrt(mse(y, y_hat)))

    x_lin = np.linspace(0, x.max(), 100)
    lin_pred = ols.predict(x_lin)

    #ax.plot(x,y,'+', color=next(iter_col))
    #ax.plot(x_lin, lin_pred, color='black')

    sns.regplot(x=pred, y='totalyearlycompensation', data=concat, ax=ax, color=next(iter_col), marker='+',)

    ax.set_title(f'{title_map[pred]}, $R^{2}$: {score:.4f}, $RMSE$: \${rmse:.2f} USD')
    ax.set_ylabel('Total Yearly Compensation (Predicted)')
    ax.set_xlabel(f'1 - Yes {pred} Tech Employee, 0 - Not {pred} Tech Employee')

# %%
corr = predictors_gend.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/1644299839.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_06e75_row0_col0, #T_06e75_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_06e75_row0_col1, #T_06e75_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_06e75_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Male</th>
#       <th class="col_heading level0 col1" >Female</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06e75_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_06e75_row0_col0" class="data row0 col0" >1.0000000000</td>
#       <td id="T_06e75_row0_col1" class="data row0 col1" >-0.9836566699</td>
#     </tr>
#     <tr>
#       <th id="T_06e75_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_06e75_row1_col0" class="data row1 col0" >-0.9836566699</td>
#       <td id="T_06e75_row1_col1" class="data row1 col1" >1.0000000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The last predictor I would like to explore further is Zodiac Signs, given the discrete nature of its' values.

# %%
predictors = df_dropna[['Zodiac']]

x = predictors
y = label

title_map = {'Zodiac': 'Zodiac Sign'}
# palette = sns.color_palette(cc.glasbey,n_colors=12) ## Acts as a vestigial line in effort to color-code plots.

pred = 'Zodiac' ## I know this isn't pretty, but I am learning from the process of passing in titles as strings as well

ols = LinearRegression().fit(x,y)
y_hat = ols.predict(x)
score = ols.score(x,y)
rmse = (np.sqrt(mse(y, y_hat)))

ax = sns.regplot(x='Zodiac', y='totalyearlycompensation', data=df, marker='+')

ax.set_title(f'{title_map[pred]}, $R^{2}$: {score:.4f}, $RMSE$: \${rmse:.2f}')
ax.set_ylabel('Total Yearly Compensation (Predicted)')
ax.set_xlabel('Zodiac Sign (0 to 12 Being the Sign Associated with Each Numbered Month)')
# Out:
# Text(0.5, 0, 'Zodiac Sign (0 to 12 Being the Sign Associated with Each Numbered Month)')

# %% [markdown]
# Having shown the seeming inefficacy of the above predictors (that I had some caution with), we will next explore the efficacy of each of the other individual predictors in terms of the scores and error used above.
#
# For this set of predictors however, I did decide to standardize by the method mentioned in Question 0 above.

# %%
predictors = df_dropna[['yearsofexperience','yearsatcompany','Age',
                        'Height','SAT','GPA']]

# predictors = (predictors - predictors.mean()) / predictors.std() # vestigial code for standardization

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(20,11))
fig.suptitle('OLS Using Rest of Individual Predictors', fontsize=20, y=0.95)

title_map = {'yearsofexperience': 'Years of Experience',
             'yearsatcompany': 'Years at Company',
             'Age': 'Age',
             'Height': 'Height',
             'SAT': 'SAT',
             'GPA': 'GPA'}

colors = ['r','g','b','y','orange','violet']

iter_col = iter(colors)

for pred, ax in zip(predictors, axs.ravel()):
    x = pd.DataFrame(predictors[pred], columns=[pred])
    y = label

    ols = LinearRegression().fit(x,y)
    y_hat = ols.predict(x)
    score = ols.score(x,y)
    rmse = (np.sqrt(mse(y, y_hat)))

    x_lin = np.linspace(x.min(), x.max(), 100)
    lin_pred = ols.predict(x_lin)

    ax.plot(x,y,'+', color=next(iter_col))
    ax.plot(x_lin, lin_pred, color='black')

    # sns.regplot(x=pred, y='totalyearlycompensation', data=df_dropna, ax=ax, color=next(iter_col), marker='+')

    ax.set_title(f'{title_map[pred]}, $R^{2}$: {score:.4f}, $RMSE$: \${rmse:.2f} USD')
    ax.set_ylabel('Total Yearly Compensation (Predicted)')
    ax.set_xlabel(f'{title_map[pred]} Normalized')

# %%
corr = predictors.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/2151522955.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_cc106_row0_col0, #T_cc106_row1_col1, #T_cc106_row2_col2, #T_cc106_row3_col3, #T_cc106_row4_col4, #T_cc106_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cc106_row0_col1, #T_cc106_row1_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_cc106_row0_col2, #T_cc106_row2_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_cc106_row0_col3, #T_cc106_row1_col3, #T_cc106_row2_col3, #T_cc106_row3_col0, #T_cc106_row3_col1, #T_cc106_row3_col2, #T_cc106_row3_col4, #T_cc106_row3_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cc106_row0_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_cc106_row0_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_cc106_row1_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_cc106_row1_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_cc106_row1_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_cc106_row2_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_cc106_row2_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_cc106_row2_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_cc106_row4_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_cc106_row4_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_cc106_row4_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_cc106_row4_col3, #T_cc106_row5_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_cc106_row4_col5, #T_cc106_row5_col4 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_cc106_row5_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_cc106_row5_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_cc106_row5_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cc106_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >yearsofexperience</th>
#       <th class="col_heading level0 col1" >yearsatcompany</th>
#       <th class="col_heading level0 col2" >Age</th>
#       <th class="col_heading level0 col3" >Height</th>
#       <th class="col_heading level0 col4" >SAT</th>
#       <th class="col_heading level0 col5" >GPA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc106_level0_row0" class="row_heading level0 row0" >yearsofexperience</th>
#       <td id="T_cc106_row0_col0" class="data row0 col0" >1.0000000000</td>
#       <td id="T_cc106_row0_col1" class="data row0 col1" >0.5374670764</td>
#       <td id="T_cc106_row0_col2" class="data row0 col2" >0.6306119604</td>
#       <td id="T_cc106_row0_col3" class="data row0 col3" >-0.0103981534</td>
#       <td id="T_cc106_row0_col4" class="data row0 col4" >0.1388751382</td>
#       <td id="T_cc106_row0_col5" class="data row0 col5" >0.1238546744</td>
#     </tr>
#     <tr>
#       <th id="T_cc106_level0_row1" class="row_heading level0 row1" >yearsatcompany</th>
#       <td id="T_cc106_row1_col0" class="data row1 col0" >0.5374670764</td>
#       <td id="T_cc106_row1_col1" class="data row1 col1" >1.0000000000</td>
#       <td id="T_cc106_row1_col2" class="data row1 col2" >0.3387777938</td>
#       <td id="T_cc106_row1_col3" class="data row1 col3" >-0.0083361083</td>
#       <td id="T_cc106_row1_col4" class="data row1 col4" >0.0435395128</td>
#       <td id="T_cc106_row1_col5" class="data row1 col5" >0.0366751208</td>
#     </tr>
#     <tr>
#       <th id="T_cc106_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_cc106_row2_col0" class="data row2 col0" >0.6306119604</td>
#       <td id="T_cc106_row2_col1" class="data row2 col1" >0.3387777938</td>
#       <td id="T_cc106_row2_col2" class="data row2 col2" >1.0000000000</td>
#       <td id="T_cc106_row2_col3" class="data row2 col3" >-0.0073548101</td>
#       <td id="T_cc106_row2_col4" class="data row2 col4" >0.0916976179</td>
#       <td id="T_cc106_row2_col5" class="data row2 col5" >0.0842780283</td>
#     </tr>
#     <tr>
#       <th id="T_cc106_level0_row3" class="row_heading level0 row3" >Height</th>
#       <td id="T_cc106_row3_col0" class="data row3 col0" >-0.0103981534</td>
#       <td id="T_cc106_row3_col1" class="data row3 col1" >-0.0083361083</td>
#       <td id="T_cc106_row3_col2" class="data row3 col2" >-0.0073548101</td>
#       <td id="T_cc106_row3_col3" class="data row3 col3" >1.0000000000</td>
#       <td id="T_cc106_row3_col4" class="data row3 col4" >-0.0043821401</td>
#       <td id="T_cc106_row3_col5" class="data row3 col5" >-0.0044356565</td>
#     </tr>
#     <tr>
#       <th id="T_cc106_level0_row4" class="row_heading level0 row4" >SAT</th>
#       <td id="T_cc106_row4_col0" class="data row4 col0" >0.1388751382</td>
#       <td id="T_cc106_row4_col1" class="data row4 col1" >0.0435395128</td>
#       <td id="T_cc106_row4_col2" class="data row4 col2" >0.0916976179</td>
#       <td id="T_cc106_row4_col3" class="data row4 col3" >-0.0043821401</td>
#       <td id="T_cc106_row4_col4" class="data row4 col4" >1.0000000000</td>
#       <td id="T_cc106_row4_col5" class="data row4 col5" >0.9126461117</td>
#     </tr>
#     <tr>
#       <th id="T_cc106_level0_row5" class="row_heading level0 row5" >GPA</th>
#       <td id="T_cc106_row5_col0" class="data row5 col0" >0.1238546744</td>
#       <td id="T_cc106_row5_col1" class="data row5 col1" >0.0366751208</td>
#       <td id="T_cc106_row5_col2" class="data row5 col2" >0.0842780283</td>
#       <td id="T_cc106_row5_col3" class="data row5 col3" >-0.0044356565</td>
#       <td id="T_cc106_row5_col4" class="data row5 col4" >0.9126461117</td>
#       <td id="T_cc106_row5_col5" class="data row5 col5" >1.0000000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From these regressions, we can see that `Years of Experience`, with an $R^{2} = 0.1621$ and $RMSE = \$121824.88$ has most predictive value of of all other $R^{2}$'s and $RMSE$'s considered for single-predictor OLS analysis.
#
# One note of caution is the high correlation implying high multicolinearity between the predictors `SAT` and `GPA` which will be addressed using regularization moving forward.
#
# Finally, we will run the full multiple-regression using all previously noted predictors mentioned above, minus categorical variables to be removed.

# %%
predictors = df_dropna[['yearsofexperience','yearsatcompany','Masters_Degree','Bachelors_Degree',
                        'Doctorate_Degree','Highschool','Race_Asian','Race_White',
                        'Race_Black','Race_Hispanic','Age','Height','Zodiac','SAT','GPA']]

grand_predictors = pd.concat([predictors, predictors_gend], axis=1) 

# predictors = (predictors - predictors.mean()) / predictors.std() ## vestigial code for standardization

X = grand_predictors
y = label

ols = LinearRegression().fit(X,y)
y_hat = ols.predict(X)
score = ols.score(X,y)
coefs_OLS = ols.coef_[0]

rmse = mse(y, y_hat) ** 0.5

X_train = sm.add_constant(X)
ls = sm.OLS(y, X_train).fit()

print(f'RMSE: ${rmse:.2f} USD')
ls.summary()
# Out:
# RMSE: $113982.53 USD
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     totalyearlycompensation   R-squared:                       0.267
# Model:                                 OLS   Adj. R-squared:                  0.266
# Method:                      Least Squares   F-statistic:                     461.1
# Date:                     Sun, 13 Mar 2022   Prob (F-statistic):               0.00
# Time:                             13:13:54   Log-Likelihood:            -2.8201e+05
# No. Observations:                    21589   AIC:                         5.641e+05
# Df Residuals:                        21571   BIC:                         5.642e+05
# Df Model:                               17
# Covariance Type:                 nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -1.542e+05   2.35e+04     -6.570      0.000      -2e+05   -1.08e+05
# yearsofexperience  8848.0098    193.920     45.627      0.000    8467.913    9228.107
# yearsatcompany    -2310.9968    277.524     -8.327      0.000   -2854.964   -1767.029
# Masters_Degree     2.743e+04   6353.459      4.317      0.000     1.5e+04    3.99e+04
# Bachelors_Degree   5051.8277   6304.741      0.801      0.423   -7305.931    1.74e+04
# Doctorate_Degree    9.87e+04   7263.857     13.588      0.000    8.45e+04    1.13e+05
# Highschool        -7758.0703   9025.628     -0.860      0.390   -2.54e+04    9932.829
# Race_Asian        -1.657e+04   4304.878     -3.848      0.000    -2.5e+04   -8127.514
# Race_White        -1.306e+04   4350.836     -3.001      0.003   -2.16e+04   -4527.736
# Race_Black        -1.852e+04   6072.106     -3.050      0.002   -3.04e+04   -6615.578
# Race_Hispanic     -1.681e+04   5417.367     -3.103      0.002   -2.74e+04   -6189.226
# Age                 -45.2223    107.889     -0.419      0.675    -256.692     166.248
# Height             -263.5703    258.486     -1.020      0.308    -770.221     243.081
# Zodiac              480.3113    225.018      2.135      0.033      39.260     921.363
# SAT                 292.9841     16.207     18.077      0.000     261.217     324.752
# GPA                6836.8581   6822.183      1.002      0.316   -6535.125    2.02e+04
# Male               -2.51e+04   1.12e+04     -2.242      0.025    -4.7e+04   -3157.574
# Female            -2.996e+04   1.13e+04     -2.649      0.008   -5.21e+04   -7788.672
# ==============================================================================
# Omnibus:                    28630.256   Durbin-Watson:                   1.684
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         40121293.596
# Skew:                           6.786   Prob(JB):                         0.00
# Kurtosis:                     213.755   Cond. No.                     3.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_hat = pd.DataFrame(y_hat, columns=['y_hat'])
y.reset_index(drop=True, inplace=True)

scatter_data = pd.concat([y,y_hat], axis=1, ignore_index=True)
scatter_data.columns = ['y','y_hat']

sns.scatterplot(x='y_hat', y='y', data=scatter_data, marker='+')
# ax.set(yscale='log')
lin = np.linspace(0,550000, 550000)
sns.lineplot(x=lin, y=lin, color='black')

plt.title(f'Full Multiple Regression, $R^{2}$: {score:.4f}, $RMSE$: \${rmse:.2f}')
plt.xlabel('Total Yearly Compensation (Predicted)')
plt.ylabel('Total Yearly Compensation (Actual)')
# Out:
# Text(0, 0.5, 'Total Yearly Compensation (Actual)')

# %% [markdown]
# In our full-regression model, we obtain an unadjusted $R^{2} = 0.267$, higher than the $R^{2} = 0.1621$ of our best single predictor, `Years of Experience`. This means that our full model explains roughly 26% of the variance in the label, compared to the approx. 16% explained by the single-predictor model.
#
# Further considering $RMSE$, we see that our $RMSE = \$113982.36$ USD is also less than the value of our best single-predictor model (which has an $RMSE = \$121824.88$ USD).

# %% [markdown]
# # Question 2
#
# Using ridge regression to do the same as in 1): How does the model change or improve compared to OLS? What is the optimal lambda?
#
# # Answer
#
# From my understanding of models operating under Ridge/LASSO (as well as the guidance of Professor Wallisch), there is no reasonable method to implement simple OLS models of Ridge or LASSO. Therefore, all following analysis will be focused on the full multiple regression model.
#
# As mentioned previously, due to regularization being sensitive to predictors without the same scale and variance, we will standardize with the equation shown below: $$\frac{X - \mu}{\sigma} $$
#
# First, let's inspect the predictors using a correlation matrix:

# %%
corr = grand_predictors.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/2613323200.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_0683a_row0_col0, #T_0683a_row1_col1, #T_0683a_row2_col2, #T_0683a_row3_col3, #T_0683a_row4_col4, #T_0683a_row5_col5, #T_0683a_row6_col6, #T_0683a_row7_col7, #T_0683a_row8_col8, #T_0683a_row9_col9, #T_0683a_row10_col10, #T_0683a_row11_col11, #T_0683a_row12_col12, #T_0683a_row13_col13, #T_0683a_row14_col14, #T_0683a_row15_col15, #T_0683a_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_0683a_row0_col2, #T_0683a_row0_col7, #T_0683a_row3_col7, #T_0683a_row5_col15 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_0683a_row0_col3, #T_0683a_row5_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_0683a_row0_col4, #T_0683a_row9_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col5, #T_0683a_row5_col0, #T_0683a_row9_col8, #T_0683a_row11_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col6, #T_0683a_row5_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_0683a_row0_col8, #T_0683a_row2_col8, #T_0683a_row10_col14, #T_0683a_row15_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col9, #T_0683a_row3_col8, #T_0683a_row7_col4, #T_0683a_row12_col9, #T_0683a_row13_col9, #T_0683a_row16_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col10 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_0683a_row0_col11, #T_0683a_row1_col11, #T_0683a_row2_col3, #T_0683a_row2_col12, #T_0683a_row3_col0, #T_0683a_row3_col2, #T_0683a_row3_col4, #T_0683a_row3_col5, #T_0683a_row3_col10, #T_0683a_row3_col13, #T_0683a_row3_col14, #T_0683a_row4_col11, #T_0683a_row6_col1, #T_0683a_row6_col7, #T_0683a_row6_col8, #T_0683a_row6_col9, #T_0683a_row7_col6, #T_0683a_row9_col11, #T_0683a_row10_col11, #T_0683a_row15_col11, #T_0683a_row15_col16, #T_0683a_row16_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col12, #T_0683a_row2_col11, #T_0683a_row3_col11, #T_0683a_row6_col12, #T_0683a_row8_col1, #T_0683a_row9_col12, #T_0683a_row12_col11, #T_0683a_row14_col12, #T_0683a_row16_col12 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col13, #T_0683a_row7_col5, #T_0683a_row10_col4, #T_0683a_row12_col4, #T_0683a_row16_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_0683a_row0_col15 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_0683a_row0_col16 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_0683a_row1_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_0683a_row1_col2, #T_0683a_row2_col15, #T_0683a_row5_col7, #T_0683a_row7_col16, #T_0683a_row8_col3, #T_0683a_row9_col16, #T_0683a_row10_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_0683a_row1_col3, #T_0683a_row11_col6, #T_0683a_row12_col6, #T_0683a_row15_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_0683a_row1_col4, #T_0683a_row1_col9, #T_0683a_row11_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_0683a_row1_col5, #T_0683a_row4_col13, #T_0683a_row12_col0, #T_0683a_row12_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_0683a_row1_col6, #T_0683a_row5_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_0683a_row1_col7, #T_0683a_row11_col15, #T_0683a_row13_col16 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_0683a_row1_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_0683a_row1_col10 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_0683a_row1_col12, #T_0683a_row3_col1, #T_0683a_row6_col0, #T_0683a_row6_col10, #T_0683a_row10_col12, #T_0683a_row11_col12, #T_0683a_row15_col12, #T_0683a_row16_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_0683a_row1_col13, #T_0683a_row2_col1, #T_0683a_row4_col14 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_0683a_row1_col14, #T_0683a_row4_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0683a_row1_col15, #T_0683a_row8_col16, #T_0683a_row10_col15 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_0683a_row1_col16, #T_0683a_row5_col16, #T_0683a_row10_col16, #T_0683a_row16_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_0683a_row2_col0, #T_0683a_row4_col9, #T_0683a_row14_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col4, #T_0683a_row5_col11, #T_0683a_row6_col13 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col5, #T_0683a_row4_col12, #T_0683a_row6_col5, #T_0683a_row7_col12, #T_0683a_row16_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col6 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_0683a_row2_col7, #T_0683a_row3_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_0683a_row2_col9, #T_0683a_row7_col1, #T_0683a_row10_col13, #T_0683a_row15_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col13, #T_0683a_row4_col10, #T_0683a_row5_col10, #T_0683a_row9_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col14, #T_0683a_row12_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_0683a_row2_col16, #T_0683a_row7_col15 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_0683a_row3_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_0683a_row3_col12, #T_0683a_row7_col11 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_0683a_row3_col15, #T_0683a_row6_col15, #T_0683a_row12_col16, #T_0683a_row14_col16 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_0683a_row3_col16, #T_0683a_row9_col3, #T_0683a_row10_col2, #T_0683a_row11_col16, #T_0683a_row12_col15, #T_0683a_row14_col15 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_0683a_row4_col0, #T_0683a_row9_col0, #T_0683a_row14_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_0683a_row4_col1, #T_0683a_row11_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_0683a_row4_col2, #T_0683a_row6_col3, #T_0683a_row7_col2, #T_0683a_row8_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0683a_row4_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_0683a_row4_col6, #T_0683a_row13_col3, #T_0683a_row14_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_0683a_row4_col7, #T_0683a_row13_col7, #T_0683a_row14_col7, #T_0683a_row15_col2, #T_0683a_row15_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_0683a_row4_col8, #T_0683a_row10_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_0683a_row4_col15 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_0683a_row4_col16 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_0683a_row5_col1, #T_0683a_row5_col14, #T_0683a_row9_col1, #T_0683a_row11_col1, #T_0683a_row11_col14, #T_0683a_row12_col13, #T_0683a_row12_col14, #T_0683a_row16_col13 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_0683a_row5_col4, #T_0683a_row11_col8, #T_0683a_row16_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_0683a_row5_col8, #T_0683a_row8_col4, #T_0683a_row13_col10, #T_0683a_row15_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_0683a_row5_col9, #T_0683a_row13_col4, #T_0683a_row14_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_0683a_row5_col12, #T_0683a_row6_col11, #T_0683a_row8_col11, #T_0683a_row8_col12, #T_0683a_row13_col11, #T_0683a_row13_col12, #T_0683a_row14_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_0683a_row5_col13, #T_0683a_row8_col10, #T_0683a_row8_col13, #T_0683a_row15_col14 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_0683a_row6_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_0683a_row6_col4, #T_0683a_row11_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_0683a_row6_col14 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_0683a_row6_col16, #T_0683a_row9_col15, #T_0683a_row13_col15 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_0683a_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_0683a_row7_col3 {
#   background-color: #e5d8d1;
#   colo

# %%
predictors = df_dropna[['yearsofexperience','yearsatcompany','Masters_Degree','Bachelors_Degree',
                        'Doctorate_Degree','Highschool','Race_Asian','Race_White',
                        'Race_Black','Race_Hispanic','Age','Height','Zodiac','SAT','GPA']]

grand_predictors = pd.concat([predictors, predictors_gend], axis=1)

cols = grand_predictors.columns
indexes = grand_predictors.index

grand_predictors = sc().fit_transform(grand_predictors)
grand_predictors = pd.DataFrame(data=grand_predictors, index=indexes, columns=cols)

X = grand_predictors
y = label

# %%
# grand_predictors = (grand_predictors - grand_predictors.mean()) / grand_predictors.std()

smallest, largest, between = 0, 500, 500

'''fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(30,25))
fig.suptitle('Ridge Regression Line of Best Fit', fontsize=25, y=0.95)
iter_ax = iter(axs.flatten())'''

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
lambdas = np.linspace(smallest, largest, between)
container = np.empty([len(lambdas),2])*np.NaN

for index in tqdm(range(len(lambdas))):
    ridge = Ridge(alpha=lambdas[index]).fit(X_train, y_train)
    y_hat = ridge.predict(X_test)
    score = ridge.score(X_test, y_test)

    container[index,0] = lambdas[index]
    error = mse(y_test, y_hat, squared=False)
    container[index,1] = error

    '''if index % 100 == 0:
        ax = next(iter_ax)

        y_hat = pd.DataFrame(y_hat, columns=['y_hat']).reset_index(drop=True)
        # y.reset_index(drop=True, inplace=True)

        scatter_data = pd.concat([y_test,y_hat], axis=1, ignore_index=True)
        scatter_data.columns = ['y_test','y_hat']

        # sns.pairplot(scatter_data)
        sns.scatterplot(x='y_hat', y='y_test', data=scatter_data, marker='+', ax=ax)
        # ax.set(yscale='log')
        lin = np.linspace(-50000,600000, (y_test.max()[0]-y_test.min()[0]))
        sns.lineplot(x=lin, y=lin, color ='black', ax=ax)

        # sns.regplot(x=y_hat, y=y_test, ax=ax, marker='+')
        ax.set_title(f'Lambda: {lambdas[index]:.2f}, $R^{2}$: {score:.4f}, $RMSE$: \${error:.2f} USD')
        ax.set_xlabel('Total Yearly Compensation (Predicted)')
        ax.set_ylabel('Total Yearly Compensation (Actual)')'''
# Out:
# 100%|██████████| 500/500 [00:04<00:00, 115.61it/s]

# %%
ax = sns.lineplot(container[:,0],container[:,1])
optimal = lambdas[np.argmax(container[:,1]==np.min(container[:,1]))]
minimum = np.min(container[:,1])

ax.set_xlabel(f'Optimal $\lambda$: {optimal:.4f}')
ax.set_ylabel(f'Minimum RMSE: \${minimum:.2f} USD')
ax.set_title('Ridge Regression')
print('Optimal Lambda:', optimal)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Optimal Lambda: 489.97995991983964

# %% [markdown]
# The model improves upon OLS: by using $\lambda ~ -8.92$, we obtain the lower $RMSE = \$106227.10$ (through Ridge) compared to $RMSE = \$113982.36$ for the full OLS multiple-regression.

# %%
ridge = Ridge(alpha=optimal).fit(X_train, y_train)
coefs_Ridge = np.array(ridge.coef_)

# Sanity check
print(f'OLS Data Shape: {coefs_OLS.shape}')
print(f'Ridge Data Shape: {coefs_Ridge.shape}')

df_coefs = pd.DataFrame(coefs_OLS, columns=['coefs_OLS'])
df_coefs['coefs_Ridge'] = coefs_Ridge.T
df_coefs['labels'] = grand_predictors.columns
df_coefs
# Out:
# OLS Data Shape: (17,)
# Ridge Data Shape: (1, 17)
#        coefs_OLS   coefs_Ridge             labels
# 0    8848.009837  48999.833656  yearsofexperience
# 1   -2310.996757  -6781.187079     yearsatcompany
# 2   27425.697021   6812.669985     Masters_Degree
# 3    5051.827715  -4235.159228   Bachelors_Degree
# 4   98702.052122  16248.989992   Doctorate_Degree
# 5   -7758.070252  -1762.725165         Highschool
# 6  -16565.393695  -7196.108912         Race_Asian
# 7  -13055.695693  -5510.529058         Race_White
# 8  -18517.354735  -2387.224691         Race_Black
# 9  -16807.665387  -2888.638806      Race_Hispanic
# 10    -45.222285   1093.117085                Age
# 11   -263.570300   -768.047413             Height
# 12    480.311313    681.070750             Zodiac
# 13    292.984061  32021.759755                SAT
# 14   6836.858089   4743.134283                GPA
# 15 -25100.001955  -3648.662303               Male
# 16 -29960.801427  -5262.452513             Female

# %% [markdown]
# # Question 3
#
# Using Lasso regression to do the same as in 1): How does the model change now? How many of the predictor betas are shrunk to exactly 0? What is the optimal lambda now?

# %%
predictors = df_dropna[['yearsofexperience','yearsatcompany','Masters_Degree','Bachelors_Degree',
                        'Doctorate_Degree','Highschool','Race_Asian','Race_White',
                        'Race_Black','Race_Hispanic','Age','Height','Zodiac','SAT','GPA']]

grand_predictors = pd.concat([predictors, predictors_gend], axis=1)

cols = grand_predictors.columns
indexes = grand_predictors.index

grand_predictors = sc().fit_transform(grand_predictors)
grand_predictors = pd.DataFrame(data=grand_predictors, index=indexes, columns=cols)

X = grand_predictors
y = label

# %%
# grand_predictors = (grand_predictors - grand_predictors.mean()) / grand_predictors.std() ## Vestigial, using StandardScalar.fit_transform instead

smallest, largest, between = 0, 800, 400

'''fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(30,25))
fig.suptitle('LASSO Regression Lines of Best Fit', fontsize=25, y=0.95)
iter_ax = iter(axs.flatten())'''

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
lambdas = np.linspace(smallest, largest, between)
container = np.empty([len(lambdas),2]) * np.NaN

for index in tqdm(range(len(lambdas))):
    lasso = Lasso(alpha=lambdas[index]).fit(X_train, y_train)
    y_hat = lasso.predict(X_test)
    score = lasso.score(X_test, y_test)

    container[index,0] = lambdas[index]
    error = mse(y_test, y_hat, squared=False)
    container[index,1] = error

    '''if index % 12 == 0:
        ax = next(iter_ax)

        y_hat = pd.DataFrame(y_hat, columns=['y_hat']).reset_index(drop=True)
        # y.reset_index(drop=True, inplace=True)

        scatter_data = pd.concat([y_test,y_hat], axis=1, ignore_index=True)
        scatter_data.columns = ['y_test','y_hat']

        # sns.pairplot(scatter_data)
        sns.scatterplot(x='y_hat', y='y_test', data=scatter_data, marker='+', ax=ax)
        # ax.set(yscale='log')
        lin = np.linspace(-50000,600000, (y_test.max()[0]-y_test.min()[0]))
        sns.lineplot(x=lin, y=lin, color ='black', ax=ax)

        # sns.regplot(x=y_hat, y=y_test, ax=ax, marker='+')
        ax.set_title(f'Lambda: {lambdas[index]:.2f}, $R^{2}$: {score:.4f}, $RMSE$: \${error:.2f} USD')
        ax.set_xlabel('Total Yearly Compensation (Predicted)')
        ax.set_ylabel('Total Yearly Compensation (Actual)')'''
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/3608735037.py:14: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso = Lasso(alpha=lambdas[index]).fit(X_train, y_train)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103746251716499.4, tolerance: 28105972806.776077
#   model = cd_fast.enet_coordinate_descent(
# 100%|██████████| 400/400 [00:08<00:00, 47.78it/s]

# %%
ax = sns.lineplot(container[:,0],container[:,1])

optimal = lambdas[np.argmax(container[:,1]==np.min(container[:,1]))]
minimum = np.min(container[:,1])

ax.set_xlabel(f'Optimal $\lambda$: {optimal:.4f}')
ax.set_ylabel(f'Minimum RMSE: \${minimum:.2f} USD')
ax.set_title('LASSO Regression')
print('Optimal Lambda:', optimal)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Optimal Lambda: 268.671679197995

# %% [markdown]
# From the above, we can see that the optimal $\lambda = -57.9798$ with an $RMSE = \$106210.38 USD$, compared to an $RMSE = \$113982.36$ for the full-predictor multiple-regression.
#
# The coefficients comparing LASSO, Ridge, and OLS models are shown below:

# %%
lasso = Lasso(alpha=optimal).fit(X_train, y_train)
coefs_LASSO = np.array(lasso.coef_)

# Sanity check
print(f'OLS Data Shape: {coefs_OLS.shape}')
print(f'LASSO Data Shape: {coefs_LASSO.shape}')

'''df_coefs = pd.DataFrame(coefs_OLS, columns=['coefs_OLS'])
df_coefs['coefs_Ridge'] = coefs_Ridge.T
df_coefs'''

df_coefs = pd.DataFrame(coefs_OLS, columns=['coefs_OLS'])
df_coefs['coefs_LASSO'] = coefs_LASSO
df_coefs['coefs_Ridge'] = coefs_Ridge.T
df_coefs['labels'] = grand_predictors.columns

df_coefs = df_coefs.reindex(columns=['labels','coefs_OLS','coefs_Ridge','coefs_LASSO'])

df_coefs
# Out:
# OLS Data Shape: (17,)
# LASSO Data Shape: (17,)
#                labels     coefs_OLS   coefs_Ridge   coefs_LASSO
# 0   yearsofexperience   8848.009837  48999.833656  51522.210085
# 1      yearsatcompany  -2310.996757  -6781.187079  -7746.726746
# 2      Masters_Degree  27425.697021   6812.669985  10514.906079
# 3    Bachelors_Degree   5051.827715  -4235.159228   -167.486101
# 4    Doctorate_Degree  98702.052122  16248.989992  18068.121237
# 5          Highschool  -7758.070252  -1762.725165   -677.273067
# 6          Race_Asian -16565.393695  -7196.108912  -5664.190141
# 7          Race_White -13055.695693  -5510.529058  -4104.428475
# 8          Race_Black -18517.354735  -2387.224691  -1657.362412
# 9       Race_Hispanic -16807.665387  -2888.638806  -2112.603549
# 10                Age    -45.222285   1093.117085     -0.000000
# 11             Height   -263.570300   -768.047413   -521.741251
# 12             Zodiac    480.311313    681.070750    484.543501
# 13                SAT    292.984061  32021.759755  36931.851659
# 14                GPA   6836.858089   4743.134283      0.000000
# 15               Male -25100.001955  -3648.662303     -0.000000
# 16             Female -29960.801427  -5262.452513  -1492.222285

# %% [markdown]
# # Question 4
#
# There is controversy as to the existence of a male/female gender pay gap in tech job compensation. Build a logistic regression model (with gender as the outcome variable) to see if there is an appreciable beta associated with total annual compensation with and without controlling for other factors.
#
# ## Answer
#
# Logistic Regression is not sensitive to the magnitude of variables, and as such I will not be standardizing.
#
# By controlling for other factors, I will be running a multiple predictor logistic regression in order to understand the relative change in the size of the $\beta$ associated with compensation to show how much of an "appreciable" effect other, outside factors have.

# %%
gender.loc[:,'gender_logistic']
# Out:
# 15710     True
# 23532     True
# 23533     True
# 23534     True
# 23535     True
#          ...
# 61981     True
# 61982     True
# 61984    False
# 61987     True
# 61991     True
# Name: gender_logistic, Length: 21483, dtype: bool

# %%
gender = df_dropna[['gender']]
gender.loc[:,'gender_logistic'] = np.NaN

gender.loc[(gender['gender'] == 'Female'), 'gender_logistic'] = 1
gender.loc[(gender['gender'] == 'Male'), 'gender_logistic'] = 0

gender.dropna(axis=0, inplace=True)

q4_predictors = df_dropna.loc[gender.index, ['totalyearlycompensation','yearsofexperience','yearsatcompany','Masters_Degree','Bachelors_Degree',
                                             'Doctorate_Degree','Highschool','Race_Asian','Race_White',
                                             'Race_Black','Race_Hispanic','Age','Height','Zodiac','SAT','GPA']]

X = q4_predictors
x = q4_predictors[['totalyearlycompensation']]
y = gender[['gender_logistic']]

model_solo = LogisticRegression().fit(x,y)
score_solo = model_solo.score(x,y)
y_solo = model_solo.predict(x)

model_full = LogisticRegression().fit(X,y)
score_full = model_full.score(X,y)
y_full = model_full.predict(X)
# Out:
# C:\Users\sunny\anaconda3\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\sunny\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\sunny\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\sunny\anaconda3\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sunny\anaconda3\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from scipy.special import expit # this is the logistic sigmoid function

x1 = np.linspace(0,4000000,10000000)
y1 = x1 * model_solo.coef_ + model_solo.intercept_
sigmoid = expit(y1)

# Plot:
plt.plot(x1,sigmoid.ravel(),color='red',linewidth=3) # the ravel function returns a flattened array
plt.scatter(x,y, alpha=0.7)
plt.hlines(0.5,260,345,colors='gray',linestyles='dotted')
plt.xlabel('Total Yearly Compensation')
# plt.xlim([260,345])
plt.ylabel('Male (0) - Female (1)')
plt.yticks(np.array([0,1]))
plt.show()
print(f'Model Coefficient: {model_solo.coef_[0][0]}')
# Out:
# Model Coefficient: -6.889477463513102e-06

# %%
full_coefs = model_full.coef_[0]

df_coefs = pd.DataFrame(full_coefs, columns=['full_coefs'])
df_coefs['labels'] = q4_predictors.columns

df_coefs = df_coefs.reindex(columns=['labels','full_coefs'])

print(f'Full Multiple Logisitc Regression Score: {score_full:.4f}')
df_coefs
# Out:
# Full Multiple Logisitc Regression Score: 0.8194
#                      labels    full_coefs
# 0   totalyearlycompensation -7.342024e-07
# 1         yearsofexperience -6.050415e-06
# 2            yearsatcompany -3.376421e-06
# 3            Masters_Degree -2.545995e-07
# 4          Bachelors_Degree -8.777555e-07
# 5          Doctorate_Degree -1.980391e-08
# 6                Highschool -6.817728e-08
# 7                Race_Asian -6.845451e-07
# 8                Race_White -4.764589e-07
# 9                Race_Black  1.446226e-08
# 10            Race_Hispanic -9.626191e-08
# 11                      Age -4.390022e-05
# 12                   Height -8.422510e-05
# 13                   Zodiac -8.078068e-06
# 14                      SAT -1.264063e-03
# 15                      GPA -3.462340e-06

# %%
fpr, tpr, thresh = metrics.roc_curve(y, y_full)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name='Full-Variable Logistic Regression')
display.plot()
plt.show()

# %%
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr,
                                  estimator_name='Full-Variable Logistic Regression')
display.plot()
plt.show()

# %%
y
# Out:
#        gender_logistic
# 15710              0.0
# 23532              0.0
# 23533              0.0
# 23534              0.0
# 23535              0.0
# ...                ...
# 61981              0.0
# 61982              0.0
# 61984              1.0
# 61987              0.0
# 61991              0.0
#
# [21483 rows x 1 columns]

# %%
np.unique(y_full)
# Out:
# array([0.])

# %%
tpr
# Out:
# array([0., 1.])

# %% [markdown]
# # Question 5
#
# Build a logistic regression model to see if you can predict high and low pay from years of relevant experience, age, height, SAT score and GPA, respectively.
#
# ## Answer
#
# For this question, I will assume `totalyearlycompensation` as the "pay" variable requested in this analysis.
#
# In order to compare high and low-pay from the aforementioned predictors, we carried out a median-split of the data by determining the median pay, marking all datapoints higher than the determined median with 1, and less than the median with 0. All values that equal the median is removed (and indexes of those entried kept). Then, the same index of datapoints obtained are removed from predictors as well.

# %%
pay = df_dropna[['totalyearlycompensation']]
pay.loc['median_split'] = np.NaN 
median_pay = pay['totalyearlycompensation'].median()

pay.loc[(pay['totalyearlycompensation'] < median_pay), 'median_split'] = 0
pay.loc[(pay['totalyearlycompensation'] > median_pay), 'median_split'] = 1

pay = pay.where(pay['totalyearlycompensation'] != median_pay).dropna()
drop_idx = pay.index

q5_predictors = df_dropna.loc[drop_idx, ['yearsofexperience','Age','Height','SAT','GPA']]
q5_predictors
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        yearsofexperience  Age  Height   SAT   GPA
# 15710                5.0   45  68.891  1166  3.04
# 23532                3.0   24  61.454  1175  3.07
# 23533                6.0   25  65.455  1268  3.34
# 23534                4.0   32  73.769  1070  2.75
# 23535                5.0   29  68.710  1187  3.23
# ...                  ...  ...     ...   ...   ...
# 61981                9.0   31  68.402  1436  3.77
# 61982               20.0   57  69.195  1363  3.50
# 61984               16.0   55  66.902  1447  3.77
# 61987               22.0   50  62.691  1513  3.85
# 61991               17.0   49  65.138  1362  3.48
#
# [21525 rows x 5 columns]

# %% [markdown]
# # Question a
#
# Is salary, height or age normally distributed? Does this surprise you? Why or why not?
#
# ## Answer
#
# Results from visual inspection will be described below. I would have preferred to conduct a KS test but that would be outside the scope of this course.
#
# ### Salary
#
# The visual inspection made the distribution seem to be normally distributed, except for a small potential of a small bimodal shift on the left. This entire skew made the rest of the distribution rather ab-normally distributed. Can't say this surprised me, given the correlation between `base salary` and `age` (shown below).

# %%
salary = df_dropna[['basesalary']]

hist = sns.histplot(salary,
                    x='basesalary',
                    kde=True)

stat, p_val = st.shapiro(salary)

hist.set(title='Base Salary Distributions of Tech Employees',
         xlabel=f'Salary (USD) - W-statistic: {stat:.4f}, p-value: {p_val:.4f}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# [Text(0.5, 1.0, 'Base Salary Distributions of Tech Employees'),
#  Text(0.5, 0, 'Salary (USD) - W-statistic: 0.9211, p-value: 0.0000')]

# %% [markdown]
# ### Height
#
# Visual inspection places the result as highly-normally distributed. I didn't expect much different: height is not a factor of consideration (that I know of at least) when considering candidates, and therefore should not create changes from an underlying distribution.
#
# Further considering the population, from what I know height is highly correlated with gender. The average female height in the US is around 64 inches, and for a male around 69 inches. The results here perfectly represent the melded bi-modal distribution of height of any given underlying distribtuion.

# %%
height = df_dropna[['Height']]

hist = sns.histplot(height,
                    x='Height',
                    kde=True)

stat, p_val = st.shapiro(height)

hist.set(title='Height Distribution of Tech Employees',
         xlabel=f'Height (Inches) - W-statistic: {stat:.4f}, p-value: {p_val:.4f}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# [Text(0.5, 1.0, 'Height Distribution of Tech Employees'),
#  Text(0.5, 0, 'Height (Inches) - W-statistic: 1.0000, p-value: 0.9938')]

# %% [markdown]
# ### Age
#
# I can't say I did not expect this. This distribution is highly skewed positively, and with the recent booms in college education and widespread understanding of the earnings potential in the technology sector, more employees are younger than those who came before (older).
#
# Also, for a hollistic analysis, different aspects such as heteroskedasticy must be accounted for as this distribution inherently analyzes a temporal dimension.

# %%
age = df_dropna[['Age']]

hist = sns.histplot(age,
                    x='Age',
                    kde=True)
hist.set(title='Age Distribution of Tech Workers')

stat, p_val = st.shapiro(age)

hist.set(title='Age Distribution of Tech Workers',
         xlabel=f'Age (Years) - W-statistic: {stat:.4f}, p-value: {p_val:.4f}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# [Text(0.5, 1.0, 'Age Distribution of Tech Workers'),
#  Text(0.5, 0, 'Age (Years) - W-statistic: 0.9875, p-value: 0.0000')]

# %%
age_salary = pd.concat([salary, age], axis=1)
corr = age_salary.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/1589670657.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_2c3a3_row0_col0, #T_2c3a3_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2c3a3_row0_col1, #T_2c3a3_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2c3a3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >basesalary</th>
#       <th class="col_heading level0 col1" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c3a3_level0_row0" class="row_heading level0 row0" >basesalary</th>
#       <td id="T_2c3a3_row0_col0" class="data row0 col0" >1.0000000000</td>
#       <td id="T_2c3a3_row0_col1" class="data row0 col1" >0.2671230621</td>
#     </tr>
#     <tr>
#       <th id="T_2c3a3_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_2c3a3_row1_col0" class="data row1 col0" >0.2671230621</td>
#       <td id="T_2c3a3_row1_col1" class="data row1 col1" >1.0000000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Question b
#
# Tell  us  something  interesting  about  this  dataset  that  is  not  already  covered  by  the questions above and that is not obvious.
#
# ## Answer
#
# For this portion of the analysis, I will be showing plots of starting salaries across the FAANG firms, at the most recent time. This will be accomplished by utilizing the full-spectrum dataset, as long as the company is available, as well as the `totalyearlycompensation` and all related salary predictors.

# %%
import re

df_starting = df[['totalyearlycompensation','yearsofexperience','company']]

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(20,10))
fig.suptitle('Histogram of Starting Salaries for Tech Employees in 2017')

colors = ['#4267B2','#000000','#FF9900','#00A4EF', '#E50914', '#0F9D58']
iter_color = iter(colors)

FAANG = ['Facebook', 'Apple', 'Amazon', 'Microsoft', 'Netflix', 'Google']

regex = ['facebook|fb', 'apple|aapl', 'amazon|amzn', 'microsoft|msft', 'netflix|nflx', 'google|goog|googl|goo']
iter_regex = iter(regex)

df_FAANG = {}
for company, ax in tqdm(zip(FAANG, axs.ravel())):
    df_FAANG[company] = df_starting[df_starting['company'].str.match(f'{next(iter_regex)}', flags=re.I) == True & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]
    med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
    mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']

    sns.histplot(df_FAANG[company],
                 x='totalyearlycompensation',                 
                 kde=True,
                 ax=ax,
                 color=next(iter_color))
    ax.set_xlim(0,0.8*1e6)

    ax.set_title(f'Starting Salary Distribution for {company}')
    ax.set_xlabel(f'Total Yearly Compensation, Mean Comp: \$ {mean_comp:.2f} USD')
    ax.set_ylabel(f'Count, Median Comp: \${med_comp} USD')
# Out:
# 0it [00:00, ?it/s]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']
# 1it [00:00,  1.04it/s]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']
# 2it [00:02,  1.04s/it]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']
# 3it [00:02,  1.03it/s]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']
# 4it [00:04,  1.01s/it]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']
# 5it [00:05,  1.00s/it]C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   med_comp = df_FAANG[company].median(axis=0)['totalyearlycompensation']
# C:\Users\sunny\AppData\Local\Temp/ipykernel_48720/485910078.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_comp = df_FAANG[company].mean(axis=0)['totalyearlycompensation']
# 6it [00:05,  1.01it/s]

# %% [markdown]
# Next, using a KS-Test, I will determine whether any/all of these companies can be considered as competing for the same 'quality of talent' as other companies that I have heard (from my friends) are not as high esteemed in pay/accomodation. If the two samples do not come from the same underlying distribution, then it can be considered that the 'range of talent' looked for by these latter companies are different.

# %%
Walmart = df_starting[(df_starting['company'].str.match(pat='walmart',na=0,flags=re.I) == True) & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]

HPE = df_starting[(df_starting['company'].str.match(pat='HPE', na=0, flags=re.I) == True) & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]
Groupon = df_starting[(df_starting['company'].str.match(pat='.*oupon', na=0,flags=re.I) == True) & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]
NerdWallet = df_starting[(df_starting['company'].str.match(pat='.*allet.*', na=0,flags=re.I) == True) & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]
Salesforce = df_starting[(df_starting['company'].str.match(pat='.*sales.*', na=0,flags=re.I) == True) & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]

# Facebook = df_starting[(df_starting['company'].str.match(pat='Facebook') == True) & ((df_starting['yearsofexperience'] == 0.0) | (df_starting['yearsofexperience'] == 1.0))]

# %% [markdown]
# We will now compare Walmart with all other FAANG companies (and Microsoft) to see whether there is such a disparity in `starting salary`.

# %%
KS_dict = {}

for company in FAANG:
    F_stat, p_value = st.kstest(rvs=df_FAANG[company]['totalyearlycompensation'], 
                                cdf=Walmart['totalyearlycompensation'], alternative='two-sided')

    KS_dict[company] = [F_stat, p_value]

for key, company in zip(KS_dict, FAANG):
    print(f'{company}, D-statistic: {KS_dict[key][0]:.4f}, p-value: {KS_dict[key][1]:.4f}')
# Out:
# Facebook, D-statistic: 0.5008, p-value: 0.0000
# Apple, D-statistic: 0.5070, p-value: 0.0000
# Amazon, D-statistic: 0.4859, p-value: 0.0000
# Microsoft, D-statistic: 0.5072, p-value: 0.0000
# Netflix, D-statistic: 0.5158, p-value: 0.0000
# Google, D-statistic: 0.4965, p-value: 0.0000

# %% [markdown]
# The above shows the implausibility for both salary distribution of Walmart to come from the same underlying distribution for any FAANG companies. The below graphs show this as well:

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(27,18))
axs = axs.flatten()
fig.suptitle('Empirical CDFs of FAANG Companies vs. Walmart on Salary')

colors = ['#4267B2','#000000','#FF9900','#00A4EF', '#E50914', '#0F9D58']
iter_color = iter(colors)

for key, company, ax in zip(KS_dict, FAANG, axs):
    walmart_ecdf = ECDF(Walmart['totalyearlycompensation'])
    comp_ecdf = ECDF(df_FAANG[company]['totalyearlycompensation'])

    sns.histplot(data=Walmart, x='totalyearlycompensation', fill=False, 
                 element='step', cumulative=True, stat='density', color='black', ax=ax, log_scale=True)

    sns.histplot(data=df_FAANG[company], x='totalyearlycompensation', fill=False, element='step', 
                 cumulative=True, stat='density', color=next(iter_color), ax=ax, log_scale=True)

    ax.set_title(f'Starting Salary CDF of Walmart vs. {company}')
    ax.set_xlabel(f'Total Yearly Compensation (Log Scale)')
    ax.set_ylabel(f'Cumulative Probability')

    ax.legend(loc='best')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Citations
#
# 1. https://medium.com/analytics-vidhya/implementing-linear-regression-using-sklearn-76264a3c073c
#
# 2. https://towardsai.net/p/data-science/how-when-and-why-should-you-normalize-standardize-rescale-your-data-3f083def38ff
#
# 3. https://pubmed.ncbi.nlm.nih.gov/9044528/
#
# 4. https://towardsdatascience.com/hyperparameter-tuning-in-lasso-and-ridge-regressions-70a4b158ae6d

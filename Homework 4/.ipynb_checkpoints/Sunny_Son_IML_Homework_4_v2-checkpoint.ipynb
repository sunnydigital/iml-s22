# %% [markdown]
# # Please **DO NOT** run any cells as everything (all final images, graphs, etc. are preloaded)
#
# # Section 0 - Preface for Imports, Data Handling, & Methodologies
#
# ## Section 0.1 Preface for Write-Up Interpretation
#
# For the remainder of this notebook, each part 1) and 2) will be answered in line with notation for the following block of code to show:
#
# 1. A brief statement (~paragraph) of what was done to answer the question (narratively explaining what you did in code to answer the question, at a high level).
#
# 2. A brief statement (~paragraph) as to why this was done (why the question was answered in this way, not by doing something else. Some kind of rationale as to why you did x and not y or z to answer the question – why is what you did a suitable approach?).
#
# For 3) and 4) the findings and interpretations will be provided in Results & Discussions for each question (model(s)) we ran.
#
# ## Section 0.2 Imports & Installation of Packages and Libraries
#
# This notebook was created using Google Colab and needs the following packages to run

# %%
# !pip install eli5
# !pip install graphviz
# !pip install scikit-optimize
# !pip install tune_sklearn
# !pip install scikit-plot
# !pip install statsmodels
# Out:
# Requirement already satisfied: eli5 in c:\programdata\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from eli5) (1.22.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from eli5) (1.16.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from eli5) (1.8.0)
# Requirement already satisfied: attrs>16.0.0 in c:\programdata\anaconda3\lib\site-packages (from eli5) (21.2.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\programdata\anaconda3\lib\site-packages (from eli5) (0.8.9)
# Requirement already satisfied: scikit-learn>=0.20 in c:\programdata\anaconda3\lib\site-packages (from eli5) (0.24.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from eli5) (2.11.3)
# Requirement already satisfied: graphviz in c:\programdata\anaconda3\lib\site-packages (from eli5) (0.19.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (2.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->eli5) (1.1.1)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: graphviz in c:\programdata\anaconda3\lib\site-packages (0.19.1)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: scikit-optimize in c:\programdata\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize) (1.22.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize) (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize) (1.8.0)
# Requirement already satisfied: pyaml>=16.9 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.2.0)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: tune_sklearn in c:\programdata\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: ray[tune] in c:\programdata\anaconda3\lib\site-packages (from tune_sklearn) (1.11.0)
# Requirement already satisfied: numpy>=1.16 in c:\programdata\anaconda3\lib\site-packages (from tune_sklearn) (1.22.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from tune_sklearn) (1.8.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from tune_sklearn) (0.24.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (3.6.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (1.0.2)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (8.1.2)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (1.43.0)
# Requirement already satisfied: jsonschema in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (3.2.0)
# Requirement already satisfied: protobuf>=3.15.3 in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (3.20.1)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (6.0)
# Requirement already satisfied: attrs in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (21.2.0)
# Requirement already satisfied: redis>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (4.1.4)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (1.3.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (2.27.1)
# Collecting tensorboardX>=1.9
#   Using cached tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: tabulate in c:\programdata\anaconda3\lib\site-packages (from ray[tune]->tune_sklearn) (0.8.9)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=7.0->ray[tune]->tune_sklearn) (0.4.4)
# Requirement already satisfied: six>=1.5.2 in c:\programdata\anaconda3\lib\site-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]->tune_sklearn) (1.16.0)
# Requirement already satisfied: deprecated>=1.2.3 in c:\programdata\anaconda3\lib\site-packages (from redis>=3.5.0->ray[tune]->tune_sklearn) (1.2.13)
# Requirement already satisfied: packaging>=20.4 in c:\programdata\anaconda3\lib\site-packages (from redis>=3.5.0->ray[tune]->tune_sklearn) (21.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\programdata\anaconda3\lib\site-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[tune]->tune_sklearn) (1.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.4->redis>=3.5.0->ray[tune]->tune_sklearn) (3.0.8)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jsonschema->ray[tune]->tune_sklearn) (62.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema->ray[tune]->tune_sklearn) (0.18.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->ray[tune]->tune_sklearn) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->ray[tune]->tune_sklearn) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->ray[tune]->tune_sklearn) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->ray[tune]->tune_sklearn) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->ray[tune]->tune_sklearn) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->ray[tune]->tune_sklearn) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->tune_sklearn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->tune_sklearn) (1.1.0)
# Installing collected packages: tensorboardX
#   Attempting uninstall: tensorboardX
#     Found existing installation: tensorboardX 1.8
#     Uninstalling tensorboardX-1.8:
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\tensorboardx-1.8.dist-info\\INSTALLER'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: scikit-plot in c:\programdata\anaconda3\lib\site-packages (0.3.7)
# Requirement already satisfied: joblib>=0.10 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (1.1.0)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (3.4.3)
# Requirement already satisfied: scikit-learn>=0.18 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (0.24.2)
# Requirement already satisfied: scipy>=0.9 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (1.8.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.22.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.8)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (9.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (2.2.0)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (1.22.3)
# Requirement already satisfied: scipy>=1.1 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (1.8.0)
# Requirement already satisfied: pandas>=0.21 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (1.3.4)
# Requirement already satisfied: patsy>=0.5 in c:\programdata\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.21->statsmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5->statsmodels) (1.16.0)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nsorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboardx (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eepspeed (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)

# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.modules.activation import Softmax
import torch.optim as optim

import scipy.stats as st

# import statsmodels.api as sm ## Need revision for Windows use
from statsmodels.distributions.empirical_distribution import ECDF
from scipy.stats import zscore

from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression, Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_validate, KFold, RepeatedKFold, GridSearchCV
from sklearn.metrics import mean_squared_error as mse
from sklearn import tree, ensemble, metrics, calibration
from sklearn.svm import SVC, LinearSVC

from IPython import display

from eli5.sklearn import PermutationImportance
from eli5 import show_prediction
import eli5

from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_objective
from skopt import BayesSearchCV

from tune_sklearn import TuneSearchCV, TuneGridSearchCV
import ray.tune as tune

from tqdm import tqdm

from matplotlib import pyplot as plt
from matplotlib import mlab
from mpl_toolkits.mplot3d import Axes3D
import scikitplot as skplt
import seaborn as sns; sns.set_theme(color_codes=True)
import graphviz
import colorcet as cc

# %% [markdown]
# ## Section 0.3
#
# Checking the availability of CUDA for PyTorch on this Device and if available, use it for Adam Gradient Descent

# %%
print(f'CUDA is Available: {torch.cuda.is_available()}')
print(f'Current CUDA Device: {torch.cuda.current_device()}')
print(f'CUDA Device Location: {torch.cuda.device(0)}')
print(f'CUDA Device Count: {torch.cuda.device_count()}')
print(f'CUDA Device Name: {torch.cuda.get_device_name(0)}')
# Out:
# CUDA is Available: False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 print(f'CUDA is Available: {torch.cuda.is_available()}')
# ----> 2 print(f'Current CUDA Device: {torch.cuda.current_device()}')
#       3 print(f'CUDA Device Location: {torch.cuda.device(0)}')
#       4 print(f'CUDA Device Count: {torch.cuda.device_count()}')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\__init__.py:481, in current_device()
#     479 def current_device() -> int:
#     480     r"""Returns the index of a currently selected device."""
# --> 481     _lazy_init()
#     482     return torch._C._cuda_getDevice()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\__init__.py:210, in _lazy_init()
#     206     raise RuntimeError(
#     207         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     208         "multiprocessing, you must use the 'spawn' start method")
#     209 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 210     raise AssertionError("Torch not compiled with CUDA enabled")
#     211 if _cudart is None:
#     212     raise AssertionError(
#     213         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device('cpu')
print(f'Currently Using Device: {device}')
# Out:
# Currently Using Device: cpu

# %% [markdown]
# ## Section 0.4 Data Handling
#
# Below, we check the presence of `NA`'s in the dataframe and afterwards, output a description of the dataframe, including `'all'` columns

# %%
df = pd.read_csv('diabetes.csv')

pd.set_option('display.max_columns', None)
print(f'Dataframe contains any NA values: {df.isnull().values.any()}')
df.describe(include='all')
# Out:
# Dataframe contains any NA values: False
#             Diabetes         HighBP       HighChol            BMI  \
# count  253680.000000  253680.000000  253680.000000  253680.000000
# mean        0.139333       0.429001       0.424121      28.382364
# std         0.346294       0.494934       0.494210       6.608694
# min         0.000000       0.000000       0.000000      12.000000
# 25%         0.000000       0.000000       0.000000      24.000000
# 50%         0.000000       0.000000       0.000000      27.000000
# 75%         0.000000       1.000000       1.000000      31.000000
# max         1.000000       1.000000       1.000000      98.000000
#
#               Smoker         Stroke     Myocardial   PhysActivity  \
# count  253680.000000  253680.000000  253680.000000  253680.000000
# mean        0.443169       0.040571       0.094186       0.756544
# std         0.496761       0.197294       0.292087       0.429169
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       1.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         1.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                Fruit     Vegetables   HeavyDrinker  HasHealthcare  \
# count  253680.000000  253680.000000  253680.000000  253680.000000
# mean        0.634256       0.811420       0.056197       0.951053
# std         0.481639       0.391175       0.230302       0.215759
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       1.000000       0.000000       1.000000
# 50%         1.000000       1.000000       0.000000       1.000000
# 75%         1.000000       1.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        NotAbleToAffordDoctor  GeneralHealth   MentalHealth  PhysicalHealth  \
# count          253680.000000  253680.000000  253680.000000   253680.000000
# mean                0.084177       2.511392       3.184772        4.242081
# std                 0.277654       1.068477       7.412847        8.717951
# min                 0.000000       1.000000       0.000000        0.000000
# 25%                 0.000000       2.000000       0.000000        0.000000
# 50%                 0.000000       2.000000       0.000000        0.000000
# 75%                 0.000000       3.000000       2.000000        3.000000
# max                 1.000000       5.000000      30.000000       30.000000
#
#        HardToClimbStairs  BiologicalSex     AgeBracket  EducationBracket  \
# count      253680.000000  253680.000000  253680.000000     253680.000000
# mean            0.168224       1.440342       8.032119          5.050434
# std             0.374066       0.496429       3.054220          0.985774
# min             0.000000       1.000000       1.000000          1.000000
# 25%             0.000000       1.000000       6.000000          4.000000
# 50%             0.000000       1.000000       8.000000          5.000000
# 75%             0.000000       2.000000      10.000000          6.000000
# max             1.000000       2.000000      13.000000          6.000000
#
#        IncomeBracket         Zodiac
# count  253680.000000  253680.000000
# mean        6.053875       6.504380
# std         2.071148       3.453446
# min         1.000000       1.000000
# 25%         5.000000       4.000000
# 50%         7.000000       7.000000
# 75%         8.000000      10.000000
# max         8.000000      12.000000

# %% [markdown]
# Viewing the entries of the first 10 rows of this new dataframe:

# %%
df.head(10)
# Out:
#    Diabetes  HighBP  HighChol  BMI  Smoker  Stroke  Myocardial  PhysActivity  \
# 0         0       1         1   40       1       0           0             0
# 1         0       0         0   25       1       0           0             1
# 2         0       1         1   28       0       0           0             0
# 3         0       1         0   27       0       0           0             1
# 4         0       1         1   24       0       0           0             1
# 5         0       1         1   25       1       0           0             1
# 6         0       1         0   30       1       0           0             0
# 7         0       1         1   25       1       0           0             1
# 8         1       1         1   30       1       0           1             0
# 9         0       0         0   24       0       0           0             0
#
#    Fruit  Vegetables  HeavyDrinker  HasHealthcare  NotAbleToAffordDoctor  \
# 0      0           1             0              1                      0
# 1      0           0             0              0                      1
# 2      1           0             0              1                      1
# 3      1           1             0              1                      0
# 4      1           1             0              1                      0
# 5      1           1             0              1                      0
# 6      0           0             0              1                      0
# 7      0           1             0              1                      0
# 8      1           1             0              1                      0
# 9      0           1             0              1                      0
#
#    GeneralHealth  MentalHealth  PhysicalHealth  HardToClimbStairs  \
# 0              5            18              15                  1
# 1              3             0               0                  0
# 2              5            30              30                  1
# 3              2             0               0                  0
# 4              2             3               0                  0
# 5              2             0               2                  0
# 6              3             0              14                  0
# 7              3             0               0                  1
# 8              5            30              30                  1
# 9              2             0               0                  0
#
#    BiologicalSex  AgeBracket  EducationBracket  IncomeBracket  Zodiac
# 0              1           9                 4              3      10
# 1              1           7                 6              1      11
# 2              1           9                 4              8       2
# 3              1          11                 3              6      11
# 4              1          11                 5              4       8
# 5              2          10                 6              8       2
# 6              1           9                 6              7       4
# 7              1          11                 4              4       7
# 8              1           9                 5              1      12
# 9              2           8                 4              3      12

# %% [markdown]
# ## Section 0.5 Standardization & Normalization
#
# For this dataset, I have opted to standardize (Z-score) all columns not associated with cardinally organized categorical variables or dummy/one-hot coded variables. The meaning of standardization in this analysis will entail subtracting every element of a column by the mean of that column, then dividing by the mean of the column:
#
# $$ \textrm{Z-Score: }\frac{\vec{X} - \mu_{X}}{\sigma_{X}} $$
#
# Variables identified as being close enough to being continuous predictors are: `BMI`, `GeneralHealth`, `MentalHealth`, and `PhysicalHealth`. I will then call the `StandardScalar().fit_transform()` function on the data to scale, and transform (standardize) the variables as shown by the equation above. This will then be the fdataframe to be executed upon in all further analysis.

# %%
continuous_predictors = ['BMI', 'GeneralHealth', 'MentalHealth','PhysicalHealth']

for item in continuous_predictors:
    df[[item]] = StandardScaler().fit_transform(df[[item]])

# %%
label = df[['Diabetes']]
label
# Out:
#         Diabetes
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 253675         0
# 253676         1
# 253677         0
# 253678         0
# 253679         1
#
# [253680 rows x 1 columns]

# %% [markdown]
# ### View a correlation matrix of the data

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# Out:
# C:\Users\sunny\AppData\Local\Temp\ipykernel_19112\3389594757.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(10)
# <style type="text/css">
# #T_e1476_row0_col0, #T_e1476_row1_col1, #T_e1476_row2_col2, #T_e1476_row3_col3, #T_e1476_row4_col4, #T_e1476_row5_col5, #T_e1476_row6_col6, #T_e1476_row7_col7, #T_e1476_row8_col8, #T_e1476_row9_col9, #T_e1476_row10_col10, #T_e1476_row11_col11, #T_e1476_row12_col12, #T_e1476_row13_col13, #T_e1476_row14_col14, #T_e1476_row15_col15, #T_e1476_row16_col16, #T_e1476_row17_col17, #T_e1476_row18_col18, #T_e1476_row19_col19, #T_e1476_row20_col20, #T_e1476_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col1, #T_e1476_row19_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_e1476_row0_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e1476_row0_col3, #T_e1476_row11_col19, #T_e1476_row18_col6, #T_e1476_row20_col11 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e1476_row0_col4, #T_e1476_row4_col0, #T_e1476_row5_col4, #T_e1476_row8_col13, #T_e1476_row10_col12, #T_e1476_row10_col14, #T_e1476_row14_col1, #T_e1476_row16_col11, #T_e1476_row19_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col5, #T_e1476_row2_col20, #T_e1476_row21_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col6, #T_e1476_row13_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e1476_row0_col7, #T_e1476_row7_col17, #T_e1476_row8_col14, #T_e1476_row14_col20, #T_e1476_row17_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col8, #T_e1476_row1_col8, #T_e1476_row1_col9, #T_e1476_row2_col8, #T_e1476_row12_col10, #T_e1476_row14_col9, #T_e1476_row18_col17 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col9, #T_e1476_row10_col8, #T_e1476_row17_col10, #T_e1476_row19_col13 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col10, #T_e1476_row0_col21, #T_e1476_row1_col21, #T_e1476_row3_col21, #T_e1476_row5_col21, #T_e1476_row6_col21, #T_e1476_row7_col3, #T_e1476_row7_col21, #T_e1476_row8_col17, #T_e1476_row8_col21, #T_e1476_row9_col21, #T_e1476_row10_col21, #T_e1476_row11_col12, #T_e1476_row11_col21, #T_e1476_row12_col11, #T_e1476_row13_col7, #T_e1476_row13_col8, #T_e1476_row13_col9, #T_e1476_row13_col19, #T_e1476_row13_col20, #T_e1476_row18_col21, #T_e1476_row19_col4, #T_e1476_row19_col21, #T_e1476_row20_col0, #T_e1476_row20_col1, #T_e1476_row20_col2, #T_e1476_row20_col5, #T_e1476_row20_col6, #T_e1476_row20_col13, #T_e1476_row20_col14, #T_e1476_row20_col15, #T_e1476_row20_col16, #T_e1476_row20_col18, #T_e1476_row20_col21 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col11, #T_e1476_row1_col12, #T_e1476_row2_col12, #T_e1476_row14_col0, #T_e1476_row14_col3, #T_e1476_row15_col18, #T_e1476_row20_col17 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col12, #T_e1476_row6_col12, #T_e1476_row8_col11, #T_e1476_row9_col11, #T_e1476_row10_col16, #T_e1476_row16_col2, #T_e1476_row21_col15 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col13 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e1476_row0_col14, #T_e1476_row5_col0, #T_e1476_row5_col14, #T_e1476_row15_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col15, #T_e1476_row14_col12 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e1476_row0_col16 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_e1476_row0_col17, #T_e1476_row1_col7, #T_e1476_row1_col19, #T_e1476_row2_col17, #T_e1476_row8_col1, #T_e1476_row9_col4, #T_e1476_row11_col3, #T_e1476_row14_col7, #T_e1476_row21_col5, #T_e1476_row21_col18 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col18, #T_e1476_row13_col2, #T_e1476_row13_col5, #T_e1476_row16_col5, #T_e1476_row21_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_e1476_row0_col19, #T_e1476_row3_col17, #T_e1476_row9_col14, #T_e1476_row11_col5, #T_e1476_row11_col8, #T_e1476_row12_col20, #T_e1476_row21_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e1476_row0_col20, #T_e1476_row2_col7, #T_e1476_row3_col4, #T_e1476_row4_col10, #T_e1476_row12_col6, #T_e1476_row17_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e1476_row1_col0, #T_e1476_row16_col14, #T_e1476_row20_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_e1476_row1_col2, #T_e1476_row2_col16, #T_e1476_row2_col18, #T_e1476_row6_col15 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e1476_row1_col3, #T_e1476_row2_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e1476_row1_col4, #T_e1476_row2_col11, #T_e1476_row2_col14, #T_e1476_row4_col6, #T_e1476_row5_col18, #T_e1476_row7_col8, #T_e1476_row18_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e1476_row1_col5, #T_e1476_row4_col1, #T_e1476_row4_col12, #T_e1476_row6_col14, #T_e1476_row10_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e1476_row1_col6, #T_e1476_row2_col15, #T_e1476_row3_col15, #T_e1476_row8_col19 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e1476_row1_col10, #T_e1476_row7_col6, #T_e1476_row7_col16, #T_e1476_row16_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e1476_row1_col11, #T_e1476_row1_col14, #T_e1476_row2_col3, #T_e1476_row4_col18, #T_e1476_row10_col7, #T_e1476_row17_col4, #T_e1476_row21_col19 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e1476_row1_col13, #T_e1476_row14_col13, #T_e1476_row14_col15 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e1476_row1_col15, #T_e1476_row8_col9, #T_e1476_row13_col3, #T_e1476_row16_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_e1476_row1_col16 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e1476_row1_col17, #T_e1476_row3_col5, #T_e1476_row11_col14 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e1476_row1_col18, #T_e1476_row14_col16 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_e1476_row1_col20, #T_e1476_row5_col3, #T_e1476_row12_col5, #T_e1476_row14_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_e1476_row2_col1, #T_e1476_row5_col13 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_e1476_row2_col4, #T_e1476_row5_col12, #T_e1476_row7_col11, #T_e1476_row14_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e1476_row2_col5, #T_e1476_row3_col20, #T_e1476_row5_col11, #T_e1476_row17_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_e1476_row2_col6, #T_e1476_row15_col1, #T_e1476_row15_col6, #T_e1476_row16_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e1476_row2_col9, #T_e1476_row5_col9, #T_e1476_row8_col4, #T_e1476_row9_col3, #T_e1476_row9_col10, #T_e1476_row16_col19 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e1476_row2_col10, #T_e1476_row11_col10, #T_e1476_row15_col17, #T_e1476_row19_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e1476_row2_col13, #T_e1476_row13_col14 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e1476_row2_col19, #T_e1476_row6_col20, #T_e1476_row12_col0, #T_e1476_row17_col0, #T_e1476_row17_col3, #T_e1476_row20_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e1476_row2_col21, #T_e1476_row4_col21, #T_e1476_row7_col2, #T_e1476_row12_col18, #T_e1476_row12_col21, #T_e1476_row13_col21, #T_e1476_row14_col21, #T_e1476_row15_col21, #T_e1476_row16_col21, #T_e1476_row17_col21 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e1476_row3_col0, #T_e1476_row6_col1, #T_e1476_row9_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e1476_row3_col1, #T_e1476_row5_col15, #T_e1476_row8_col20, #T_e1476_row9_col7, #T_e1476_row12_col15, #T_e1476_row16_col0, #T_e1476_row18_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e1476_row3_col2, #T_e1476_row4_col20, #T_e1476_row5_col20, #T_e1476_row11_col1, #T_e1476_row12_col3, #T_e1476_row14_col5, #T_e1476_row17_col15, #T_e1476_row18_col20 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_e1476_row3_col6, #T_e1476_row4_col5, #T_e1476_row4_col11, #T_e1476_row4_col17, #T_e1476_row8_col18 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e1476_row3_col7, #T_e1476_row4_col19, #T_e1476_row9_col1, #T_e1476_row18_col3, #T_e1476_

# %% [markdown]
# ## Section 0.6 Label View
#
# In this section, we will view the output of the labels and take into account disparity in outcome.
#
# We can see from the outcome that the classes are highly skewed to the negative and would require the use of f1 scores to disting predictive capability under this skewness.

# %%
one_count = len(label.loc[(label['Diabetes'] == 1)])
zero_count = len(label.loc[(label['Diabetes'] == 0)])
print(f'Number of positive class: {one_count}')
print(f'Number of negative class: {zero_count}')
# Out:
# Number of positive class: 35346
# Number of negative class: 218334

# %% [markdown]
# # Question 1
#
# Build and train a Perceptron (one input layer, one output layer, no hidden layers and no activation functions) to classify diabetes from the rest of the dataset. What is the AUC of this model?
#
# ## Answer
#
# ## Section 1.0 Scikit Learn `Perceptron` Fitting & Train-Test Split
#
# We will then use the Scikit-Learn Module `train_test_split` to create a split dataset of 0.3 proportional size for the test set, as well as using the `random_state` equalling `1234`. This is to cross-validate the model and ensure generalizability.
#
# Next, we utilize `sklearn.linear_model`'s `Perceptron` class to create a Perceptron fitting the number of input features and output values (one, given linear output).

# %%
X = df.loc[:, 'HighBP':]
y = label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
perceptron = Perceptron(random_state=1234)
perceptron.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Perceptron(random_state=1234)

# %% [markdown]
# ## Section 1.1 `CalibratedClassifierCV` Fitting of `Perceptron` Class
#
# Below we use the `CalibratedClassifierCV` class to make it possible to both `predict` the outputs of a given `y_test` set of unseen data, and `predict_proba` the probabilities of each new, unseen feature set `y_test`.
#
# Following from the calculated `predict_proba` variable, we use `metrics.roc_curve` to output the AUC ROC of our model.

# %%
cal_perceptron = calibration.CalibratedClassifierCV(base_estimator=perceptron, method='sigmoid', n_jobs=-1, cv='prefit')
cal_perceptron.fit(X_test, y_test)

perceptron_pred = cal_perceptron.predict(X_test)
perceptron_proba = cal_perceptron.predict_proba(X_test)[:,1]

fpr, tpr, thresh = metrics.roc_curve(y_true=y_test, y_score=perceptron_proba, pos_label=1)
perceptron_auc = metrics.auc(x=fpr, y=tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=perceptron_auc,
                                  estimator_name='Perceptron Model')

print(perceptron_auc)
display.plot(color='darkorange', lw=2)
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
plt.show()
# Out:
# 0.7051916832377519

# %% [markdown]
# ## Section 1.2 `PermutationImportance` of Features
#
# Next, we use the `PermutationImportance` package from the `eli5` library to calculate the permutated importance of individual features. The theory goes that for every feature, (for k=5 cross-fold validation) the individual rows (for that feature column ONLY) are shuffled (permutated) randomly.
#
# This will give the intuition of making the feature invalid (as close to removing as possible without actually removing it). The drop in scores entail the importance of the feature to the overall performance of the model. Finally, a $\pm$ value is provided from the extremes of the 5-fold cross-validation.

# %%
perm1 = PermutationImportance(estimator=perceptron, random_state=1234)
perm1.fit(X_test, y_test)
eli5.show_weights(perm1, feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 97.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 97.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 96.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 96.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 96.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 95.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 95.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 94.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0002
#
#                     &plusmn; 0.0001

# %% [markdown]
# ## Section 1.3 Results & Discussion
#
# From training the model we determine an AUC of 0.70519, and given a perceptron without an activation function the same as a linear regression model, this is a good AUC score to obtain.

# %% [markdown]
# # Question 2
#
# Build and train a feedforward neural network with at least one hidden layer to classify diabetes from the rest of the dataset. Make sure to try different numbers of hidden layers and different activation functions (at a minimum reLU and sigmoid). Doing so: How does AUC vary as a function of the number of hidden layers and is it dependent on the kind of activation function used (make sure to include “no activation function” in your comparison). How does this network perform relative to the Perceptron?
#
# ## Answer
#
# ## Section 2.0 Feedforward `MLClassifier` Fitting & Train-Test Split
#
# We will then use the Scikit-Learn Module `train_test_split` to create a split dataset of 0.3 proportional size for the test set, as well as using the `random_state` equalling `1234`. This is to cross-validate the model and ensure generalizability.
#
# Next, we utilize `sklearn.neural_network`'s `MLClassifier` class to create a Multilayer Perceptron (Feedforward Neural Network) fitting the number of input features and output values (one, given linear output).
#
# We create a total of 12 models, one for each cardinal product between the number of hidden layers: `[1, 2, 3]` and the type of activation to use: `['identity', 'relu', 'logistic', 'tanh']`. Every model will have `hidden_layer_size` = 64. For each model, we define an entry in a dictionary, `fnn_models2` that, as the `key` contains the model name, and as the `value` contains the instantiated & fit model.

# %%
X = df.loc[:, 'HighBP':]
y = label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
hidden_layers = [1, 2, 3]
# hidden_size = [2, 4, 8, 16, 32, 64, 128] ## Opted not to tunr for hidden layer sizes
activation = ['identity', 'relu', 'logistic', 'tanh']

fnn_models2 = {}
model_name = lambda x: f'fnn_{x[0]}_{x[1]}'

for num in hidden_layers:
  for function in activation:
    name = [function, num]
    if num == 1:
      fnn = MLPClassifier(hidden_layer_sizes=(128), random_state=1234, activation=function)
      fnn.fit(X_train, y_train)
      fnn_models2[model_name(name)] = fnn
    if num == 2:
      fnn = MLPClassifier(hidden_layer_sizes=(128,128), random_state=1234, activation=function)
      fnn.fit(X_train, y_train)
      fnn_models2[model_name(name)] = fnn
    if num == 3:
      fnn = MLPClassifier(hidden_layer_sizes=(128,128,128), random_state=1234, activation=function)
      fnn.fit(X_train, y_train)
      fnn_models2[model_name(name)] = fnn
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %% [markdown]
# ## Section 2.1 `CalibratedClassifierCV` Fitting of `MLClassifier` Class
#
# Below we use the `CalibratedClassifierCV` class to make it possible to both `predict` the outputs of a given `y_test` set of unseen data, and `predict_proba` the probabilities of each new, unseen feature set `y_test`.
#
# We use the dictionary `fnn_cals2` to store the output of every `CalibratedClassifierCV` as the `value` to the `key` of the same name as the `fnn_models2` dictionary.
#
# Following from each calculated `predict_proba` variable stored in the `fnn_cals2` dictionary, we use `metrics.roc_curve` to output the AUC ROC of each model.

# %%
fnn_cals2 = {}
for key, value in fnn_models2.items():
  cal_fnn = calibration.CalibratedClassifierCV(base_estimator=value, method='sigmoid', n_jobs=-1, cv='prefit')
  cal_fnn.fit(X_test, y_test)

  fnn_pred = cal_fnn.predict(X_test)
  fnn_proba = cal_fnn.predict_proba(X_test)[:,1]

  fnn_cals2[key] = (fnn_pred, fnn_proba)

fnn2_aucname_map = {'fnn_identity_1': 'Hidden Layers: 1, Activation Function: None',
                   'fnn_identity_2': 'Hidden Layers: 2, Activation Function: None',
                   'fnn_identity_3': 'Hidden Layers: 3, Activation Function: None',    
                   'fnn_relu_1': 'Hidden Layers: 1, Activation Function: ReLU',
                   'fnn_relu_2': 'Hidden Layers: 2, Activation Function: ReLU',
                   'fnn_relu_3': 'Hidden Layers: 3, Activation Function: ReLU',
                   'fnn_logistic_1': 'Hidden Layers: 1, Activation Function: Logistic',
                   'fnn_logistic_2': 'Hidden Layers: 2, Activation Function: Logistic',
                   'fnn_logistic_3': 'Hidden Layers: 3, Activation Function: Logistic',
                   'fnn_tanh_1': 'Hidden Layers: 1, Activation Function: TanH',
                   'fnn_tanh_2': 'Hidden Layers: 2, Activation Function: TanH',
                   'fnn_tanh_3': 'Hidden Layers: 3, Activation Function: TanH'}

fig, axs = plt.subplots(nrows=4, ncols=3, figsize=(25,22))
fig.suptitle('AUC ROCs of Feedforward Networks with Differing Layers and Activations', fontsize=25, y=0.95)

fnn_cal2_keys = fnn_cals2.keys()

for key, ax in zip(fnn_cal2_keys, axs.ravel()):
    
    pred_proba = fnn_cals2[key][1]

    fpr, tpr, _ = metrics.roc_curve(y_true=y_test, y_score=pred_proba, pos_label=1)
    auc = metrics.auc(x=fpr, y=tpr)

    display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr,
                                      estimator_name=f'{fnn2_aucname_map[key]}')
    
    display.plot(color='darkorange', lw=2, ax=ax)
    ax.set_title(f'Model AUC ROC: {auc}')
    ax.plot([0,1], [0,1], color="navy", lw=2, linestyle="--")

# %% [markdown]
# ## Section 2.2 `PermutationImportance` of Features
#
# Next, we use the `PermutationImportance` package from the `eli5` library to calculate the permutated importance of individual features. The theory goes that for every feature, (for k=5 cross-fold validation) the individual rows (for that feature column ONLY) are shuffled (permutated) randomly.
#
# We will create a dictionary `fnn2_perm` full of `PermurationIMportance` objects. Each will correspond to an individual model in `fnn_models2`.
#
# This will give the intuition of making the feature invalid (as close to removing as possible without actually removing it). The drop in scores entail the importance of the feature to the overall performance of the model. Finally, a $\pm$ value is provided from the extremes of the 5-fold cross-validation.

# %%
fnn2_perm = {}
for key, value in fnn_models2.items():
    fnn = value
    
    perm2 = PermutationImportance(estimator=fnn, random_state=1234)
    perm2.fit(X_test, y_test)
    
    fnn2_perm[key] = perm2

# %%
eli5.show_weights(fnn2_perm['fnn_identity_1'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0048
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0016
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0002
#
#                     &plusmn; 0.0003

# %%
eli5.show_weights(fnn2_perm['fnn_identity_2'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0061
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0051
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001

# %%
eli5.show_weights(fnn2_perm['fnn_identity_3'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0018
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0002

# %%
eli5.show_weights(fnn2_perm['fnn_relu_1'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0073
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0021
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001

# %%
eli5.show_weights(fnn2_perm['fnn_relu_2'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0087
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0077
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002

# %%
eli5.show_weights(fnn2_perm['fnn_relu_3'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0082
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0078
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0002

# %%
eli5.show_weights(fnn2_perm['fnn_logistic_1'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0018
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002

# %%
eli5.show_weights(fnn2_perm['fnn_logistic_2'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0077
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001

# %%
eli5.show_weights(fnn2_perm['fnn_logistic_3'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0070
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0068
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0021
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusm

# %%
eli5.show_weights(fnn2_perm['fnn_tanh_1'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0043
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0021
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0016
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 97.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0002
#
#                     &plusmn; 0.0001

# %%
eli5.show_weights(fnn2_perm['fnn_tanh_2'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0066
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0065
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EducationBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zodiac
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0002

# %%
eli5.show_weights(fnn2_perm['fnn_tanh_3'], feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0079
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0062
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0013
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HeavyDrinker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vegetables
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0002
#
#                     &plusmn; 0.0005

# %% [markdown]
# ## Section 2.3 Results & Discussion
#
# From training 12 different models with different combinations of activation functions and number of layers, and taking al ook at the AUC ROC of each model, we see that a feedforward neural network with different number of layers improves the AUC ROC marginally, but the experiment controlled for the size of each hidden layer (setting each at 128), so dicrepencies may exist due to that.
#
# Furthermore, a general pattern emerged of each dimensionalization of hidden layers having `logistic` > `Tanh` > `ReLU` > `identity` in AUC ROC performance (with general increases in the number of hidden layers increasing performance marginally).

# %% [markdown]
# # Question 3
#
# Build and train a “deep” network (at least 2 hidden layers) to classify diabetes from the rest of the dataset. Given the nature of this dataset, is there a benefit of using a CNN or RNN for the classification?
#
# ## Answer
#
# ## Section 3.0 Feedforward `MLClassifier` Fitting & Train-Test Split
#
# We will then use the Scikit-Learn Module `train_test_split` to create a split dataset of 0.3 proportional size for the test set, as well as using the `random_state` equalling `1234`. This is to cross-validate the model and ensure generalizability.
#
# Next, we utilize `sklearn.neural_network`'s `MLClassifier` class to create a Multilayer Perceptron (Feedforward Neural Network) fitting the number of input features and output values. This model will have 2 hidden layers, with `hidden_layer_size` = 128 for each layer.

# %%
X = df.loc[:, 'HighBP':]
y = label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %% [markdown]
# ## Section 3.1 `CalibratedClassifierCV` Fitting of `MLClassifier` Class
#
# Below we use the `CalibratedClassifierCV` class to make it possible to both `predict` the outputs of a given `y_test` set of unseen data, and `predict_proba` the probabilities of each new, unseen feature set `y_test`.
#
# We use the variable `cal_dnn3` to store the output of the `CalibratedClassifierCV`.
#
# Following from each calculated `predict_proba` variable stored in the `dnn3_proba` dictionary, we use `metrics.roc_curve` to output the AUC ROC of the model.

# %%
function = 'relu'

dnn3 = MLPClassifier(hidden_layer_sizes=(128,128,), random_state=1234, activation=function)
dnn3.fit(X_train, y_train)

cal_dnn3 = calibration.CalibratedClassifierCV(base_estimator=dnn3, method='sigmoid', n_jobs=-1, cv='prefit')
cal_dnn3.fit(X_test, y_test)

dnn3_pred = cal_dnn3.predict(X_test)
dnn3_proba = cal_dnn3.predict_proba(X_test)[:,1]

fpr, tpr, thresh = metrics.roc_curve(y_true=y_test, y_score=dnn3_proba, pos_label=1)
dnn3_auc = metrics.auc(x=fpr, y=tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=dnn3_auc,
                                  estimator_name='Deep Neural Network Model')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print(dnn3_auc)
display.plot(color='darkorange', lw=2)
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
plt.show()
# Out:
# 0.7490023076317904

# %% [markdown]
# ## Section 3.2 `PermutationImportance` of Features
#
# Next, we use the `PermutationImportance` package from the `eli5` library to calculate the permutated importance of individual features. The theory goes that for every feature, (for k=5 cross-fold validation) the individual rows (for that feature column ONLY) are shuffled (permutated) randomly. The model we use is `dnn3` as defined and processed above.
#
# This will give the intuition of making the feature invalid (as close to removing as possible without actually removing it). The drop in scores entail the importance of the feature to the overall performance of the model. Finally, a $\pm$ value is provided from the extremes of the 5-fold cross-validation.

# %%
perm3 = PermutationImportance(estimator=dnn3, random_state=1234)
perm3.fit(X_test, y_test)
eli5.show_weights(perm3, feature_names=X.columns.tolist(), top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0080
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GeneralHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BMI
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0039
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AgeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysicalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0013
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighChol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BiologicalSex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Smoker
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MentalHealth
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IncomeBracket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HardToClimbStairs
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HasHealthcare
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Stroke
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Myocardial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NotAbleToAffordDoctor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PhysActivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HighBP
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fruit
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0010

# %% [markdown]
# ## Section 3.3 Results & Discussion
#
# Looking at the dataset we have, there does not seem to be much of a temporal or spacial relationship between points of data. Furthermore, there is not present a format of imagery or sequencing (such as linguistic data) that can make use of CNNs (former case) or RNNs (latter case). The tabular nature of the information within the data makes it furthermore difficult to evoke on RNNs.[<sup>[1]</sup>](#fn1)

# %% [markdown]
# # Question 4
#
# Build and train a feedforward neural network with one hidden layer to predict BMI from the rest of the dataset. Use RMSE to assess the accuracy of your model. Does the RMSE depend on the activation function used?
#
# ## Answer
#
# ## Section 4.0 Feedforward `MLClassifier` Train-Test Split
#
# We will then use the Scikit-Learn Module `train_test_split` to create a split dataset of 0.3 proportional size for the test set, as well as using the `random_state` equalling `1234`. This is to cross-validate the model and ensure generalizability.

# %%
X = df.loc[:, ['BMI']]

y = label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %% [markdown]
# ## Section 4.1 `MLClassifier` Implementation of `CalibratedClassifierCV`
#
# Next, we utilize `sklearn.neural_network`'s `MLClassifier` class to create a Multilayer Perceptron (Feedforward Neural Network) fitting the number of input features and output values. This model will have 1 hidden layer, with the `hiddden_layer_size` = 64. However, we will be fitting/differentiating between a list of activations: `['identity', 'relu', 'logistic', 'tanh']`.
#
# Within each loop cycling through the list of activation functions, we implement `CalibratedClassifierCV` to obtain `predict` values using each set of data.

# %%
activation_list = ['identity', 'relu', 'logistic', 'tanh']

rmse4_dict = {}
for activation in activation_list:

    fnn4 = MLPClassifier(hidden_layer_sizes=(64,), random_state=1234, activation=activation)
    fnn4.fit(X_train, y_train)

    cal_fnn4 = calibration.CalibratedClassifierCV(base_estimator=fnn4, method='sigmoid', n_jobs=-1, cv='prefit')
    cal_fnn4.fit(X_test, y_test)

    fnn4_pred = cal_fnn4.predict(X_test)

    RMSE = mse(y_pred=fnn4_pred, y_true=y_test, squared=False)
    rmse4_dict[activation] = RMSE
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %% [markdown]
# ## Section 4.2 RMSE Outputs
#
# Below we show the RMSE of attributable to each activation function.

# %%
for key, value in rmse4_dict.items():
    print(f'{key}: {value}')
# Out:
# identity: 0.3804420462184122
# relu: 0.37810350721404345
# logistic: 0.37662364436447177
# tanh: 0.37662364436447177

# %% [markdown]
# ## Section 4.3 Results & Discussion

# %% [markdown]
# # Question 5
#
# Build and train a neural network of your choice to predict BMI from the rest of your dataset. How low can you get RMSE and what design choices does RMSE seem to depend on?
#
# ## Answer
#
# ## Section 5.0 Feedforward `MLClassifier` Train-Test Split
#
# We will then use the Scikit-Learn Module `train_test_split` to create a split dataset of 0.3 proportional size for the test set, as well as using the `random_state` equalling `1234`. This is to cross-validate the model and ensure generalizability.

# %%
X = df.loc[:, ['BMI']]
y = label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %% [markdown]
# ## Section 5.1 `MLClassifier` Implementation of `CalibratedClassifierCV`
#
# Next, we utilize `sklearn.neural_network`'s `MLClassifier` class to create a Multilayer Perceptron (Feedforward Neural Network) fitting the number of input features and output values. This model will have 1 hidden layer, with the `hiddden_layer_sizes` = 64, 128, 256, 64. However, we will be fitting/differentiating between a list of activations: `['identity', 'relu', 'logistic', 'tanh']`.
#
# Within each loop cycling through the list of activation functions, we implement `CalibratedClassifierCV` to obtain `predict` values using each set of data.

# %%
activation_list = ['identity', 'relu', 'logistic', 'tanh']

rmse5_dict = {}
for activation in activation_list:

    fnn5 = MLPClassifier(hidden_layer_sizes=(64, 256, 64,), random_state=1234, activation=activation)
    fnn5.fit(X_train, y_train)

    cal_fnn5 = calibration.CalibratedClassifierCV(base_estimator=fnn5, method='sigmoid', n_jobs=-1, cv='prefit')
    cal_fnn5.fit(X_test, y_test)

    fnn5_pred = cal_fnn5.predict(X_test)
    fnn5_proba = cal_fnn5.predict_proba(X_test)[:,1]

    fpr, tpr, thresh = metrics.roc_curve(y_true=y_test, y_score=fnn5_proba, pos_label=1)
    fnn5_auc = metrics.auc(x=fpr, y=tpr)
    display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=fnn5_auc,
                                      estimator_name='Deep Neural Network Model')

    RMSE = mse(y_pred=fnn5_pred, y_true=y_test, squared=False)
    rmse5_dict[activation] = RMSE
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
for key, value in rmse5_dict.items():
    print(f'{key}: {value}')
# Out:
# identity: 0.3804420462184122
# relu: 0.37662364436447177
# logistic: 0.37662364436447177
# tanh: 0.37662364436447177

# %% [markdown]
# # Question A
#
# Are there any predictors/features that have effectively no impact on the accuracy of these models? If so, please list them and comment briefly on your findings
#
# ## Answer
#
# ## Section A.1 Data Preview & Analysis
#
# From each of the models with `PermutationImportance` graphical outputs shown above, we see that the features with consistent low impact on the accuracy of these models are: `Zodiac`, `Fruit`, `IncomeBracket`, `HardToClimbStairs`, `PhysicalActivity`, `Stroke`, `EducationBracket`, `HasHealthcare`, `MentalHealth`, `PhysicalHealth`. It seems (from both my own intuition and the impact of these scores due to high multicolinearity and in some cases, even the inducement of pure randomness as in the case of `Zodiac`). Each of these predictors has had multiple (n>2) instances of having a `PermutationImporance` score (for a given model where the score was computed) of less than 0.

# %% [markdown]
# # Question B
#
# Write a summary statement on the overall pros and cons of using neural networks to learn from the same dataset as in the prior homework, relative to using classical methods (logistic regression, SVM, trees, forests, boosting methods). Any overall lessons?
#
# ## Answer
#
# ## Section B.0
#
# Neural networks are a powerful tool for learning from data (coming with the capability of appximating functions to ensure low bias), but they come with a few potential drawbacks. First, neural networks can be more difficult to interpret than other machine learning methods, making it harder to understand why the model is making certain predictions. Second, neural networks can be more computationally intensive than other methods, meaning that they may take longer to train or require more powerful hardware. Finally, neural networks can be more susceptible to overfitting than other methods (higher variance), meaning that they may not generalize well to new data. Overall, neural networks offer a powerful tool for learning from data, but they come with some potential drawbacks that should be considered before using them for a particular problem.
#
# By the way, most of the above statement (outside human-commented parentheses) was writtten by OpenAI's GPT-3. Neat, no?

# %% [markdown]
# # Sources Cited
#
# ## Section C.0
#
# &emsp;&emsp;[1] <span id="fn1">https://machinelearningmastery.com/when-to-use-mlp-cnn-and-rnn-neural-networks/</span>

# %% [markdown]
# ## Appendix
#
# ### Appendix 8.1 Unused PyTorch `nn.Module` Code

# %%
X = df.loc[:, 'HighBP':]
y = label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X_train = torch.tensor(X_train.values, dtype=torch.float).to(device)
X_test = torch.tensor(X_test.values, dtype=torch.float).to(device)
y_train = torch.tensor(y_train.values, dtype=torch.float).to(device)
y_test = torch.tensor(y_test.values, dtype=torch.float).to(device)

X = torch.tensor(X.values, dtype=torch.float).to(device)
y = torch.tensor(y.values, dtype=torch.float).to(device)

# %%
class Perceptron(nn.Module):
    def __init__(self, input_size):
        super(Perceptron, self).__init__()
        self.input_size = input_size
        self.fc = nn.Linear(self.input_size, 1)
        
    def forward(self, x):
        output = self.fc(x)
        return output

# %%
torch.manual_seed(1234)
input_size = X_test.shape[1]

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model = Perceptron(input_size = input_size)
model.to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
train_loss_history = []
mse_history = []
best_rmse = np.Infinity
n_no_improve = 0
early_stop_patience = 5
stop = False
epoch = 1

while ~stop:
    model.train()
    print(f'Starting [EPOCH]: {epoch}')
    
    y_pred = model(X_train)
    
    loss = criterion(y_pred, y_train)
    print(f'[EPOCH]: {epoch}, [LOSS]: {loss.item():,.2f}')
    display.clear_output(wait=True)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    train_loss_history.append(loss.item())
    
    model.eval()
    y_pred = model(X_test)
    mean_squared_error = mse(squared=False, y_true=y_test.detach().cpu(), 
                                            y_pred=y_pred.detach().cpu())
    
    if mean_squared_error < best_rmse:
      best_rmse = mean_squared_error
      torch.save(model, 'perceptron_model.pt')

    if len(mse_history) > 0 and mean_squared_error >= mse_history[-1]:
      n_no_improve += 1
    else:
      n_no_improve = 0

    mse_history.append(mean_squared_error)
    
    if n_no_improve == early_stop_patience:
      break
    
    epoch += 1
    
print("Best RMSE is: ", best_rmse)

# %%
from torch.nn.modules.activation import Softmax
class FeedforwardNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(FeedforwardNN, self).__init__()
        self.input_size = input_size
        self.network = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size),
            nn.ReLU(),
            nn.Tanh()
        )
        
    def forward(self, x):
        return self.network(x)
